# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

os.chdir("/Users/chrtjen/Desktop/STB_GTT/Japan")

# %%
filenames = os.listdir()

dfs = []
df_names = []
for filename in filenames:
    if 'csv' in filename:
        df_names.append(filename)
        dfs.append(pd.read_csv(filename))
  
print(f'read the following dataframes: {df_names}')
# Out:
# read the following dataframes: ['WhatarethebestbreakfastoptionsaroundUenostation.csv', 'DaytriptoNikkofromTokyo2questions.csv', 'Gionkyoto.csv', 'WheretoStayfor1Night.csv', 'SidetripinOsaka.csv', 'CostforTaxifromAirport.csv', 'Hiroshimamiyajimatriponjune4.csv', 'SecondhandLouisVuittonhandbags.csv', 'WillAustralianphonesworkinJapan.csv', 'CrosscountrySkiinginHakubaquestions.csv', 'TraditionalmusicinKyotoinNovember.csv', 'BestareatoliveinFukuokaforme.csv', 'PrebookticketfromHanedaAirportstationtoKyotoNozomi.csv', 'PassportDamage.csv', 'VisitingMtFujiandaroundwhilehavingtheJRPass.csv', 'BusinsteadofJRpass.csv', 'AirBandBvshotels.csv', 'TobuNikkoSpaciawithTokyoWidePassandTokaiBusPass.csv', 'fukubukuroLuckybagswhen.csv', 'LateAprilpotential9daysitineraryinHokkaido.csv', 'Summer2021TraveltoJapan.csv', 'NewYearsEveTokyo2020.csv', 'ItineraryhelpFukuokatrip.csv', 'WhichflighttoJapanwouldyoutakefromthese2.csv', 'VisitFriendVisa.csv', 'Tokyustayshinjuku.csv', 'OdaibaOedoOnsenMonogatariisclosing.csv', 'NewYear.csv', 'Japan11dayrelaxitinerary.csv', 'AnytouristwanttobuyManekiNekoasagiftfromJapan.csv', 'TravelonHidaLimitedExpress.csv', 'HalfdayKamakurafromTokyo.csv', 'AlanMashuNationalPark.csv', 'OnlineresertavationshinkansenfromKyototoTokyo.csv', 'isHakoneRopewaystillsuspendedfromtheVolcanowarnings.csv', 'FlowersinearlyJulyTryavoidolympics.csv', 'BulletandbombblastedWWIIfactorybuildingtoopen.csv', 'KansaiAirporttoShinOsakaStation.csv', 'Whichofthesehotelswouldyourecommendfor6nightstay.csv', 'RainydayinTokyo.csv', 'TokyoKyotoKawaguchikoFujiTokyoTrains.csv', 'Covidtesting.csv', 'luggagestorageatTakayama.csv', 'GoodaffordableplacesforKobeBeefinKobe.csv', 'ResearchingforDecember2021trip.csv', 'DoNakamiseshopsopenonLabourThanksgiving.csv', 'QuestionaboutOneDayItineraryforKobe.csv', 'AvailabilityofpublictransportinNisekoHirafuarea.csv', 'BusfaresHakatastationtoYanagouchibusstop柳河内バス.csv', 'HashimaIslandakaGunkanjimalandingclosedonSep23.csv', 'PlattKodamadiscounttickettoTokyo.csv', 'KamakuraWalksHiking.csv', 'HanedaairportTaxis.csv', '5dayRoadTripfromtoOkayamaShikokuDrivingHighlights.csv', 'NagoyaShirakawagoTakayamainJanuary.csv', 'NaritaAirporttoKeikyuExHotelShinagawa.csv', 'HikinginJapanTakayamaHakoneorNikko.csv', 'ChairCarLiftatMtTakao.csv', 'ThreedaysinTokyoisitworthgoingtoDisneySea.csv', 'InternationalTransferatNaritaInternationalAirport.csv', 'OfftheBeatenPathinJapan.csv', '50eurobillsexchange.csv', 'TsumagofestivalinNovember.csv', 'ETCvsHEPCarrental.csv', 'Itinerary5D4N.csv', '30dayJapanitinerarywheretostay.csv', 'KeioLimitesExpressfromShinjuku.csv', '18octto22oct.csv', 'Cellphonerentals.csv', 'BuyingShinkansentickettoNaganofromNaritaAirport.csv', 'Privatetransportbetweenmountains.csv', 'WinterHikinginYamagataareainLateDecember.csv', 'GettingtoLakeShojifromIiyamaviakofu.csv', 'HowmuchYenneeded.csv', '2or3basesinJapanwithminimaltimeinTokyo.csv', '7DaysItineraryatFukuoka.csv', 'Akitabusfromcruiseport.csv', 'Hoponoffbus.csv', 'WeSwapCard.csv', 'Sakebarservinghighqualitysake.csv', 'handsfreeairplanelavatorydoors.csv', 'NicehotelSapporoHakodateotaru.csv', 'PurchasingtickettoKitakyushuwisteriagarden.csv', 'TokyoandNikkonextweek.csv', 'Declaringconvictionwhenenteringjapan.csv', 'TraditionalTeaKyotoorTokyo.csv', 'NaritatoYokohamaCruiseTerminal.csv', 'MtFujitourpickupatHamamatsuchoBusTerminal.csv', 'Japantrip.csv', 'CeramicsPotteryDaytrip.csv', 'Helpwithmyitineraryand7daysJRPass.csv', 'KimiideraKumanonachiTaishaandIseshrinesin2days.csv', 'TokyotoHakodatetraininGoldenweekJRpass.csv', 'Bullfightingfestivalreturnsundershadowofvirus.csv', 'GiantGionFestivalfloatrebuiltfor2022paradedebut.csv', 'IsSapporoworthavisitina2weekitenerary.csv', 'AdviseofTypesofCarstorent.csv', '10dayJapanDecJanSuggestionspls.csv', 'FromNRTairporttoshinjuku.csv', 'TottoriinDecember.csv', 'WhattowearinTokyo.csv', 'FirefliesJuneJuly.csv', 'Japanborderreopening.csv', 'LuggageDeliveryService.csv', 'Bestbusscheduletomaximizekyotoinaday.csv', 'RentingaCarinJapanPickingandDroppingOff. ...

# %%
#create the master dataframe

comments_master = pd.concat(dfs, ignore_index=True, sort=False).dropna(subset=['Discussion']).reset_index(drop=True)
comments_master
# Out:
#                 User                 User_loc                    Date  \
# 0            BrianLy          Philadelphia...              1 year ago
# 1              Nao H             Tokyo, Japan              1 year ago
# 2            BrianLy          Philadelphia...              1 year ago
# 3       Global715255             Tokyo, Japan              1 year ago
# 4       Global715255             Tokyo, Japan              1 year ago
# ...              ...                      ...                     ...
# 105558     mabei0123           Tsukuba, Japan              1 year ago
# 105559  Global715255             Tokyo, Japan              1 year ago
# 105560       SammyFD         Hong Kong, China              1 year ago
# 105561  Global715255             Tokyo, Japan              1 year ago
# 105562           NaN  Osaka Prefecture, Kinki  Jan 21, 2021, 12:41 AM
#
#                                                Discussion  Hashtag  \
# 0       I’m staying just east of Ueno station (Mimaru ...      NaN
# 1       you will see starbucks, McDonald and some comb...      NaN
# 2       These are the things I want to avoid. It would...      NaN
# 3       Walk on the main street. You will find many ca...      NaN
# 4       There is a breakfast buffet at Hotel Sun Route...      NaN
# ...                                                   ...      ...
# 105558  There is no Pass which pays off for only Tokyo...      NaN
# 105559  If you haven't made reservation yet, Shimbashi...      NaN
# 105560  Shin-Okubo isn't particularly inconvenient tho...      NaN
# 105561  Check below to see where the sightseeing spots...      NaN
# 105562  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#                                              Source_title   Type  \
# 0       What are the best breakfast options around Uen...  forum
# 1       What are the best breakfast options around Uen...  forum
# 2       What are the best breakfast options around Uen...  forum
# 3       What are the best breakfast options around Uen...  forum
# 4       What are the best breakfast options around Uen...  forum
# ...                                                   ...    ...
# 105558            Tokyo - I am confused - please guide me  forum
# 105559            Tokyo - I am confused - please guide me  forum
# 105560            Tokyo - I am confused - please guide me  forum
# 105561            Tokyo - I am confused - please guide me  forum
# 105562                                                NaN    NaN
#
#                                              User_profile       Source  \
# 0       https://www.tripadvisor.com/Profile/BrianLy?ta...  tripadvisor
# 1       https://www.tripadvisor.com/Profile/Na0H?tab=f...  tripadvisor
# 2       https://www.tripadvisor.com/Profile/BrianLy?ta...  tripadvisor
# 3       https://www.tripadvisor.com/Profile/Global7152...  tripadvisor
# 4       https://www.tripadvisor.com/Profile/Global7152...  tripadvisor
# ...                                                   ...          ...
# 105558  https://www.tripadvisor.com/Profile/mabei0123?...  tripadvisor
# 105559  https://www.tripadvisor.com/Profile/Global7152...  tripadvisor
# 105560  https://www.tripadvisor.com/Profile/SammyFD?ta...  tripadvisor
# 105561  https://www.tripadvisor.com/Profile/Global7152...  tripadvisor
# 105562                                                NaN          NaN
#
#        Product_category  Product Brand Country  \
# 0                travel  tourism   stb      th
# 1                travel  tourism   stb      th
# 2                travel  tourism   stb      th
# 3                travel  tourism   stb      th
# 4                travel  tourism   stb      th
# ...                 ...      ...   ...     ...
# 105558           travel  tourism   stb      th
# 105559           travel  tourism   stb      th
# 105560           travel  tourism   stb      th
# 105561           travel  tourism   stb      th
# 105562              NaN      NaN   NaN     NaN
#
#                                                Source_URL
# 0       https://www.tripadvisor.com/ShowTopic-g294232-...
# 1       https://www.tripadvisor.com/ShowTopic-g294232-...
# 2       https://www.tripadvisor.com/ShowTopic-g294232-...
# 3       https://www.tripadvisor.com/ShowTopic-g294232-...
# 4       https://www.tripadvisor.com/ShowTopic-g294232-...
# ...                                                   ...
# 105558  https://www.tripadvisor.com/ShowTopic-g294232-...
# 105559  https://www.tripadvisor.com/ShowTopic-g294232-...
# 105560  https://www.tripadvisor.com/ShowTopic-g294232-...
# 105561  https://www.tripadvisor.com/ShowTopic-g294232-...
# 105562                                                NaN
#
# [105563 rows x 14 columns]

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
#        User                 User_loc                    Date  \
# 1453    NaN                     Asia  Sep 16, 2020, 12:41 AM
# 1652    NaN  Tokyo Prefecture, Kanto   Dec 10, 2020, 1:41 AM
# 1690    NaN  Tokyo Prefecture, Kanto   Oct 7, 2020, 12:41 AM
# 1773    NaN  Tokyo Prefecture, Kanto    Nov 1, 2020, 1:41 AM
# 1946    NaN  Tokyo Prefecture, Kanto  Sep 30, 2020, 12:41 AM
# ...     ...                      ...                     ...
# 105503  NaN                     Asia   Oct 10, 2020, 1:41 AM
# 105509  NaN             Kinki, Japan  Nov 16, 2020, 12:40 AM
# 105519  NaN                     Asia  Oct 21, 2020, 12:40 AM
# 105529  NaN  Tokyo, Tokyo Prefecture  Nov 19, 2020, 12:40 AM
# 105562  NaN  Osaka Prefecture, Kinki  Jan 21, 2021, 12:41 AM
#
#                                                Discussion  Hashtag  \
# 1453    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 1652    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 1690    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 1773    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 1946    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# ...                                                   ...      ...
# 105503  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 105509  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 105519  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 105529  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 105562  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#        Source_title Type User_profile Source Product_category Product Brand  \
# 1453            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 1652            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 1690            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 1773            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 1946            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# ...             ...  ...          ...    ...              ...     ...   ...
# 105503          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 105509          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 105519          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 105529          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 105562          NaN  NaN          NaN    NaN              NaN     NaN   NaN
#
#        Country Source_URL
# 1453       NaN        NaN
# 1652       NaN        NaN
# 1690       NaN        NaN
# 1773       NaN        NaN
# 1946       NaN        NaN
# ...        ...        ...
# 105503     NaN        NaN
# 105509     NaN        NaN
# 105519     NaN        NaN
# 105529     NaN        NaN
# 105562     NaN        NaN
#
# [4069 rows x 14 columns]

# %%
comments_master.dtypes
# Out:
# User                 object
# User_loc             object
# Date                 object
# Discussion           object
# Hashtag             float64
# Source_title         object
# Type                 object
# User_profile         object
# Source               object
# Product_category     object
# Product              object
# Brand                object
# Country              object
# Source_URL           object
# dtype: object

# %%
#only select comments made in 2021
comments_master = comments_master[comments_master['Date'].str.contains('2021')]

#drop automated comments
comments_master = comments_master[~comments_master['Discussion'].str.contains('Message from Tripadvisor staff')]

comments_master
# Out:
#                     User           User_loc                    Date  \
# 75                Alex M      Madrid, Spain   Jan 13, 2021, 6:12 AM
# 76               ETflyer     Fukuoka, Japan   Jan 13, 2021, 7:14 AM
# 77                Alex M      Madrid, Spain   Jan 13, 2021, 7:59 AM
# 78               ETflyer     Fukuoka, Japan   Jan 13, 2021, 8:26 AM
# 79                Alex M      Madrid, Spain   Jan 13, 2021, 8:35 AM
# ...                  ...                ...                     ...
# 105170          nishin91        Kobe, Japan   Mar 31, 2021, 9:21 AM
# 105171           SammyFD   Hong Kong, China  Mar 31, 2021, 10:20 PM
# 105358        William512  Vancouver, Canada   Feb 19, 2021, 1:12 AM
# 105481     Icemanclimber                NaN   Jan 29, 2021, 5:36 PM
# 105482  JapanCustomTours              Japan   Jan 29, 2021, 6:10 PM
#
#                                                Discussion  Hashtag  \
# 75      Ok, planning my stay in Fukuoka for a couple o...      NaN
# 76      Best is very subjective. I'd pick up residenti...      NaN
# 77      Excellent bunch of details! What about the opp...      NaN
# 78      One more place to add to my previous post. JR ...      NaN
# 79           Perfect, thanks! Will update the map shortly      NaN
# ...                                                   ...      ...
# 105170  I don't fly JAL or ANA so often these days, bu...      NaN
# 105171  I thought that was equipment dependent. I star...      NaN
# 105358  https://japantoday.com/category/features/lifes...      NaN
# 105481        Will fuji be open this summer for climbing?      NaN
# 105482  No one knows yet. It was closed for climbing i...      NaN
#
#                                              Source_title   Type  \
# 75                 Best area to live in Fukuoka (for me)?  forum
# 76                 Best area to live in Fukuoka (for me)?  forum
# 77                 Best area to live in Fukuoka (for me)?  forum
# 78                 Best area to live in Fukuoka (for me)?  forum
# 79                 Best area to live in Fukuoka (for me)?  forum
# ...                                                   ...    ...
# 105170  Domestic flight cuts in-flight audio entertain...  forum
# 105171  Domestic flight cuts in-flight audio entertain...  forum
# 105358        private working booth in convenience stores  forum
# 105481                                      Climbing fuji  forum
# 105482                                      Climbing fuji  forum
#
#                                              User_profile       Source  \
# 75      https://www.tripadvisor.com/Profile/ErrantDev?...  tripadvisor
# 76      https://www.tripadvisor.com/Profile/ETflyer?ta...  tripadvisor
# 77      https://www.tripadvisor.com/Profile/ErrantDev?...  tripadvisor
# 78      https://www.tripadvisor.com/Profile/ETflyer?ta...  tripadvisor
# 79      https://www.tripadvisor.com/Profile/ErrantDev?...  tripadvisor
# ...                                                   ...          ...
# 105170  https://www.tripadvisor.com/Profile/nishin91?t...  tripadvisor
# 105171  https://www.tripadvisor.com/Profile/SammyFD?ta...  tripadvisor
# 105358  https://www.tripadvisor.com/Profile/William512...  tripadvisor
# 105481  https://www.tripadvisor.com/Profile/Icemanclim...  tripadvisor
# 105482  https://www.tripadvisor.com/Profile/JapanCusto...  tripadvisor
#
#        Product_category  Product Brand Country  \
# 75               travel  tourism   stb      th
# 76               travel  tourism   stb      th
# 77               travel  tourism   stb      th
# 78               travel  tourism   stb      th
# 79               travel  tourism   stb      th
# ...                 ...      ...   ...     ...
# 105170           travel  tourism   stb      th
# 105171           travel  tourism   stb      th
# 105358           travel  tourism   stb      th
# 105481           travel  tourism   stb      th
# 105482           travel  tourism   stb      th
#
#                                                Source_URL
# 75      https://www.tripadvisor.com/ShowTopic-g298207-...
# 76      https://www.tripadvisor.com/ShowTopic-g298207-...
# 77      https://www.tripadvisor.com/ShowTopic-g298207-...
# 78      https://www.tripadvisor.com/ShowTopic-g298207-...
# 79      https://www.tripadvisor.com/ShowTopic-g298207-...
# ...                                                   ...
# 105170  https://www.tripadvisor.com/ShowTopic-g294232-...
# 105171  https://www.tripadvisor.com/ShowTopic-g294232-...
# 105358  https://www.tripadvisor.com/ShowTopic-g294232-...
# 105481  https://www.tripadvisor.com/ShowTopic-g294232-...
# 105482  https://www.tripadvisor.com/ShowTopic-g294232-...
#
# [6414 rows x 14 columns]

# %%
#country is mislabelled so have to change country

comments_master['Country'] = comments_master['Country'].replace('th','jp')

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/STB_GTT_Step1Output/Japan.csv",index=False)
