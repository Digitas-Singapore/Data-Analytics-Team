# %%
#Indonesia had already been combined into one file, so no need to extract data anymore

# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

#define which folder this script will be working in
os.chdir("/Users/chrtjen/Desktop/STB_GTT")

# %% [markdown]
# filenames = os.listdir()
#
# dfs = []
# df_names = []
# for filename in filenames:
#     if 'csv' in filename:
#         df_names.append(filename)
#         dfs.append(pd.read_csv(filename))
#
# print(f'read the following dataframes: {df_names}')

# %%
#create the master dataframe

comments_master = pd.read_csv('Indonesia.csv').dropna(subset=['Discussion']).reset_index(drop=True)
comments_master
# Out:
#                  User                       User_loc         Date  \
# 0            ASHES198                            NaN  2 years ago
# 1          Brendan248           Melbourne, Australia  2 years ago
# 2            ASHES198                            NaN  2 years ago
# 3             Sarwa G             Bandung, Indonesia  2 years ago
# 4         SurfingWild             Bandung, Indonesia  2 years ago
# ...               ...                            ...          ...
# 199360        FengZhe  West Nusa Tenggara, Indonesia  2 years ago
# 199361  baliAustralia       Nusa Dua Peninsula, Bali  2 years ago
# 199362        FengZhe                            NaN  2 years ago
# 199363         Janice                          China  2 years ago
# 199364            NaN            Greater Adelaide...   1 year ago
#
#                                                Discussion  Hashtag  \
# 0       I am a teacher in Yangon and i Booked ticket f...      NaN
# ...

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
#        User               User_loc                    Date  \
# 2562    NaN        Indonesia, Asia             2 years ago
# 2731    NaN        Indonesia, Asia             2 years ago
# 2739    NaN                   Asia              1 year ago
# 3348    NaN        Indonesia, Asia              1 year ago
# 4080    NaN                   Asia  Jul 22, 2020, 12:40 AM
# ...     ...                    ...                     ...
# 199229  NaN        Bali, Indonesia              1 year ago
# 199236  NaN  Gianyar Regency, Bali             2 years ago
# 199313  NaN       Karangasem, Bali   Feb 1, 2021, 12:42 AM
# 199317  NaN        East Java, Java  Nov 19, 2020, 12:41 AM
# 199323  NaN        Indonesia, Asia              1 year ago
#
#                                                Discussion  Hashtag  \
# 2562    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 2731    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# ...

# %%
comments_master.dtypes
# Out:
# User                 object
# User_loc             object
# Date                 object
# Discussion           object
# Hashtag             float64
# Source_title         object
# Type                 object
# User_profile         object
# Source               object
# Product_category     object
# Product              object
# Brand                object
# Country              object
# Source_URL           object
# dtype: object

# %%
#only select comments made in 2021
comments_master = comments_master[comments_master['Date'].str.contains('2021')]

#drop automated comments
comments_master = comments_master[~comments_master['Discussion'].str.contains('Message from Tripadvisor staff')]

comments_master
# Out:
#                   User              User_loc                    Date  \
# 301           lpjjrose         Sebastopol...   Mar 25, 2021, 2:00 PM
# 302         NotaPigsty       Munich, Germany   Mar 26, 2021, 4:13 AM
# 303           lpjjrose         Sebastopol...   Mar 26, 2021, 1:35 PM
# 304           Gidget61         Booker Bay...   Mar 26, 2021, 7:43 PM
# 305         NotaPigsty       Munich, Germany   Mar 27, 2021, 4:39 AM
# ...                ...                   ...                     ...
# 198861         Lynne P    Ballina, Australia  Jun 20, 2021, 10:53 PM
# 198862      NotaPigsty       Munich, Germany   Jun 21, 2021, 5:00 AM
# 198971         Pablo G      Montreal, Canada   May 20, 2021, 4:55 PM
# 198972  World traveler    Jakarta, Indonesia   May 20, 2021, 9:29 PM
# 198973         Simon H  Singapore, Singapore   May 21, 2021, 9:12 AM
#
#                                                Discussion  Hashtag  \
# 301     We have booked all our travel and hotels in Sa...      NaN
# ...

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/STB_GTT_Step1Output/Indonesia.csv",index=False)
