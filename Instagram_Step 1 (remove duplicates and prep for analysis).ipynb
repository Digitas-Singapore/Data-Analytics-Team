# %%
#Instagram data already comes in one file, so no need to extract data anymore

# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

#define which folder this script will be working in
os.chdir("/Users/chrtjen/Desktop/STB_GTT")

# %% [markdown]
# filenames = os.listdir()
#
# dfs = []
# df_names = []
# for filename in filenames:
#     if 'csv' in filename:
#         df_names.append(filename)
#         dfs.append(pd.read_csv(filename))
#
# print(f'read the following dataframes: {df_names}')

# %%
#create the master dataframe

comments_master = pd.read_csv('Instagram.csv').dropna(subset=['Discussion_translated']).reset_index(drop=True)
comments_master
# Out:
#        User User_loc           Date  \
# 0      none     none  31/8/21 17:40
# 1      none     none   31/8/21 9:39
# 2      none     none   31/8/21 2:29
# 3      none     none  30/8/21 18:58
# 4      none     none  30/8/21 10:15
# ...     ...      ...            ...
# 11924  none     none    1/1/21 7:06
# 11925  none     none    1/1/21 6:50
# 11926  none     none    1/1/21 6:44
# 11927  none     none    1/1/21 6:42
# 11928  none     none    1/1/21 6:35
#
#                                               Discussion  \
# 0      @soul_power_music yes exactly, a short break r...
# 1                  Milos is definitely top on my list! 😍
# 2      The view is so pretty. 😍 I hope you are having...
# 3      Ohh love this shot 👌 you should try our hammoc...
# 4             Does anyone know where these guys are from
# ...                                                  ...
# 11924  Sometimes you just walk till you drop. Horribl...
# 11925  It’s a shameful mark on the USA where we have ...
# 11926  We should not have homelessness in this countr...
# 11927  Imagine the ingenuity and survival instincts t...
# 11928  There is so many empty building in this world ...
#
#                                    Discussion_translated Hashtag  \
# 0      @soul_power_music yes exactly, a short break r...     NaN
# 1                  Milos is definitely top on my list! 😍     NaN
# 2      The view is so pretty. 😍 I hope you are having...     NaN
# 3      Ohh love this shot 👌 you should try our hammoc...     NaN
# 4             Does anyone know where these guys are from     NaN
# ...                                                  ...     ...
# 11924  Sometimes you just walk till you drop. Horribl...     NaN
# 11925  It’s a shameful mark on the USA where we have ...     NaN
# 11926  We should not have homelessness in this countr...     NaN
# 11927  Imagine the ingenuity and survival instincts t...     NaN
# 11928  There is so many empty building in this world ...     NaN
#
#             Source_title          Type User_profile     Source  \
# 0      bucketlistjourney  social media         none  Instagram
# 1        theblondeabroad  social media         none  Instagram
# 2        theblondeabroad  social media         none  Instagram
# 3        theblondeabroad  social media         none  Instagram
# 4         thatbackpacker  social media         none  Instagram
# ...                  ...           ...          ...        ...
# 11924      dguttenfelder  social media         none  Instagram
# 11925      dguttenfelder  social media         none  Instagram
# 11926      dguttenfelder  social media         none  Instagram
# 11927      dguttenfelder  social media         none  Instagram
# 11928      dguttenfelder  social media         none  Instagram
#
#       Product_category  Product Brand        Country  \
# 0               travel  tourism   STB  International
# 1               travel  tourism   STB  International
# 2               travel  tourism   STB  International
# 3               travel  tourism   STB  International
# 4               travel  tourism   STB  International
# ...                ...      ...   ...            ...
# 11924           travel  tourism   STB  International
# 11925           travel  tourism   STB  International
# 11926           travel  tourism   STB  International
# 11927           travel  tourism   STB  International
# 11928           travel  tourism   STB  International
#
#                                               Source_URL  \
# 0      https://www.instagram.com/p/CPYO14xME5I/c/1824...
# 1      https://www.instagram.com/p/CSxf0fxswJo/c/1789...
# 2      https://www.instagram.com/p/CSxf0fxswJo/c/1787...
# 3      https://www.instagram.com/p/CTDpPrcvsjQ/c/1801...
# 4      https://www.instagram.com/p/CNfnu4qFwGU/c/1792...
# ...                                                  ...
# 11924  https://www.instagram.com/p/CJep5joHFhb/c/1813...
# 11925  https://www.instagram.com/p/CJep5joHFhb/c/1797...
# 11926  https://www.instagram.com/p/CJep5joHFhb/c/1786...
# 11927  https://www.instagram.com/p/CJep5joHFhb/c/1818...
# 11928  https://www.instagram.com/p/CJep5joHFhb/c/1788...
#
#                                 keywords
# 0      ['restaurant', 'hike', 'explore']
# 1                 ['beach', 'adventure']
# 2                 ['beach', 'adventure']
# 3                ['adventure', 'family']
# 4                             ['market']
# ...                                  ...
# 11924                   ['park', 'snow']
# 11925                   ['park', 'snow']
# 11926                   ['park', 'snow']
# 11927                   ['park', 'snow']
# 11928                   ['park', 'snow']
#
# [11929 rows x 16 columns]

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
# Empty DataFrame
# Columns: [User, User_loc, Date, Discussion, Discussion_translated, Hashtag, Source_title, Type, User_profile, Source, Product_category, Product, Brand, Country, Source_URL, keywords]
# Index: []

# %%
comments_master.dtypes
# Out:
# User                     object
# User_loc                 object
# Date                     object
# Discussion               object
# Discussion_translated    object
# Hashtag                  object
# Source_title             object
# Type                     object
# User_profile             object
# Source                   object
# Product_category         object
# Product                  object
# Brand                    object
# Country                  object
# Source_URL               object
# keywords                 object
# dtype: object

# %% [markdown]
# #only select comments made in 2021
# comments_master = comments_master[comments_master['Date'].str.contains('2021')]
#
# comments_master

# %%
comments_master
# Out:
#        User User_loc           Date  \
# 0      none     none  31/8/21 17:40
# 1      none     none   31/8/21 9:39
# 2      none     none   31/8/21 2:29
# 3      none     none  30/8/21 18:58
# 4      none     none  30/8/21 10:15
# ...     ...      ...            ...
# 11924  none     none    1/1/21 7:06
# 11925  none     none    1/1/21 6:50
# 11926  none     none    1/1/21 6:44
# 11927  none     none    1/1/21 6:42
# 11928  none     none    1/1/21 6:35
#
#                                               Discussion  \
# 0      @soul_power_music yes exactly, a short break r...
# 1                  Milos is definitely top on my list! 😍
# 2      The view is so pretty. 😍 I hope you are having...
# 3      Ohh love this shot 👌 you should try our hammoc...
# 4             Does anyone know where these guys are from
# ...                                                  ...
# 11924  Sometimes you just walk till you drop. Horribl...
# 11925  It’s a shameful mark on the USA where we have ...
# 11926  We should not have homelessness in this countr...
# 11927  Imagine the ingenuity and survival instincts t...
# 11928  There is so many empty building in this world ...
#
#                                    Discussion_translated Hashtag  \
# 0      @soul_power_music yes exactly, a short break r...     NaN
# 1                  Milos is definitely top on my list! 😍     NaN
# 2      The view is so pretty. 😍 I hope you are having...     NaN
# 3      Ohh love this shot 👌 you should try our hammoc...     NaN
# 4             Does anyone know where these guys are from     NaN
# ...                                                  ...     ...
# 11924  Sometimes you just walk till you drop. Horribl...     NaN
# 11925  It’s a shameful mark on the USA where we have ...     NaN
# 11926  We should not have homelessness in this countr...     NaN
# 11927  Imagine the ingenuity and survival instincts t...     NaN
# 11928  There is so many empty building in this world ...     NaN
#
#             Source_title          Type User_profile     Source  \
# 0      bucketlistjourney  social media         none  Instagram
# 1        theblondeabroad  social media         none  Instagram
# 2        theblondeabroad  social media         none  Instagram
# 3        theblondeabroad  social media         none  Instagram
# 4         thatbackpacker  social media         none  Instagram
# ...                  ...           ...          ...        ...
# 11924      dguttenfelder  social media         none  Instagram
# 11925      dguttenfelder  social media         none  Instagram
# 11926      dguttenfelder  social media         none  Instagram
# 11927      dguttenfelder  social media         none  Instagram
# 11928      dguttenfelder  social media         none  Instagram
#
#       Product_category  Product Brand        Country  \
# 0               travel  tourism   STB  International
# 1               travel  tourism   STB  International
# 2               travel  tourism   STB  International
# 3               travel  tourism   STB  International
# 4               travel  tourism   STB  International
# ...                ...      ...   ...            ...
# 11924           travel  tourism   STB  International
# 11925           travel  tourism   STB  International
# 11926           travel  tourism   STB  International
# 11927           travel  tourism   STB  International
# 11928           travel  tourism   STB  International
#
#                                               Source_URL  \
# 0      https://www.instagram.com/p/CPYO14xME5I/c/1824...
# 1      https://www.instagram.com/p/CSxf0fxswJo/c/1789...
# 2      https://www.instagram.com/p/CSxf0fxswJo/c/1787...
# 3      https://www.instagram.com/p/CTDpPrcvsjQ/c/1801...
# 4      https://www.instagram.com/p/CNfnu4qFwGU/c/1792...
# ...                                                  ...
# 11924  https://www.instagram.com/p/CJep5joHFhb/c/1813...
# 11925  https://www.instagram.com/p/CJep5joHFhb/c/1797...
# 11926  https://www.instagram.com/p/CJep5joHFhb/c/1786...
# 11927  https://www.instagram.com/p/CJep5joHFhb/c/1818...
# 11928  https://www.instagram.com/p/CJep5joHFhb/c/1788...
#
#                                 keywords
# 0      ['restaurant', 'hike', 'explore']
# 1                 ['beach', 'adventure']
# 2                 ['beach', 'adventure']
# 3                ['adventure', 'family']
# 4                             ['market']
# ...                                  ...
# 11924                   ['park', 'snow']
# 11925                   ['park', 'snow']
# 11926                   ['park', 'snow']
# 11927                   ['park', 'snow']
# 11928                   ['park', 'snow']
#
# [11929 rows x 16 columns]

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/STB_GTT_Step1Output/Instagram.csv",index=False)
