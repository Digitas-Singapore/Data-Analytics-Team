# %%
#Facebook data already comes in one file, so no need to extract data anymore

# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

#define which folder this script will be working in
os.chdir("/Users/chrtjen/Desktop/STB_GTT")

# %% [markdown]
# filenames = os.listdir()
#
# dfs = []
# df_names = []
# for filename in filenames:
#     if 'csv' in filename:
#         df_names.append(filename)
#         dfs.append(pd.read_csv(filename))
#
# print(f'read the following dataframes: {df_names}')

# %%
#create the master dataframe

comments_master = pd.read_csv('Facebook.csv').dropna(subset=['Discussion']).reset_index(drop=True)
comments_master
# Out:
#        User User_loc                 Date  \
# 0      none       UK  2021-03-05 07:21:10
# 1      none       UK  2021-03-05 06:52:48
# 2      none       UK  2021-03-05 03:43:05
# 3      none       UK  2021-03-05 02:43:19
# 4      none       UK  2021-03-05 05:36:27
# ...     ...      ...                  ...
# 53261  none       JP  2019-10-07 00:00:00
# 53262  none       JP  2020-05-27 00:00:00
# 53263  none       JP  2020-05-22 00:00:00
# 53264  none       JP  2020-05-21 00:00:00
# 53265  none       JP  2020-05-21 00:00:00
#
#                                               Discussion  \
# 0           Go smash 💥 it 👌 with plenty of good vibes 😎
# 1      Good luck, Mexico 🇲🇽 is one of my favourite pl...
# 2      Blame covid !!! Everyone else is for everythin...
# 3      You look so serene, i sure all that positive e...
# 4                                            Suerte!! 🤞🏻
# ...                                                  ...
# 53261                                      シェアしてもいいですか❓️
# 53262                                       海好きにはたまりませぬ🥰
# 53263  Oh! Fantastic ! な光景。私は40年前の昔、フロリダ州・マイアミ～キーウェスト...
# 53264  わぁ!! 素敵ですぅ✨💕 私も、昔にマイアミから豪華客船🛳️でナッソーに行きました！海岸の真...
# 53265                                            海綺麗ですね💕
#
#                                    Discussion_translated Hashtag  \
# 0           Go smash 💥 it 👌 with plenty of good vibes 😎      NaN
# 1      Good luck, Mexico 🇲🇽 is one of my favourite pl...     NaN
# 2      Blame covid !!! Everyone else is for everythin...     NaN
# 3      You look so serene, i sure all that positive e...     NaN
# 4                                            Suerte!! 🤞🏻     NaN
# ...                                                  ...     ...
# 53261                                  Can I share it ❓️     NaN
# 53262                It';s irresistible for sea lovers 🥰     NaN
# 53263  Oh! Fantastic! Forty years ago, when I visited...     NaN
# 53264  Wow !! It';s wonderful ✨💕 I also went to Nassa...     NaN
# 53265                             The sea is beautiful 💕     NaN
#
#                                      Source_title          Type User_profile  \
# 0                                   Becs Cronshaw  social media         none
# 1                                   Becs Cronshaw  social media         none
# 2                                   Becs Cronshaw  social media         none
# 3                                   Becs Cronshaw  social media         none
# 4                                   Becs Cronshaw  social media         none
# ...                                           ...           ...          ...
# 53261  世界を旅するバックパッカーたちの集い - 世界のどこかでリアルに出会って乾杯しよう！  social media         none
# 53262  世界を旅するバックパッカーたちの集い - 世界のどこかでリアルに出会って乾杯しよう！  social media         none
# 53263  世界を旅するバックパッカーたちの集い - 世界のどこかでリアルに出会って乾杯しよう！  social media         none
# 53264  世界を旅するバックパッカーたちの集い - 世界のどこかでリアルに出会って乾杯しよう！  social media         none
# 53265  世界を旅するバックパッカーたちの集い - 世界のどこかでリアルに出会って乾杯しよう！  social media         none
#
#          Source Product_category  Product Brand Country  \
# 0      Facebook           travel  tourism   STB      UK
# 1      Facebook           travel  tourism   STB      UK
# 2      Facebook           travel  tourism   STB      UK
# 3      Facebook           travel  tourism   STB      UK
# 4      Facebook           travel  tourism   STB      UK
# ...         ...              ...      ...   ...     ...
# 53261  Facebook           travel  tourism   STB      JP
# 53262  Facebook           travel  tourism   STB      JP
# 53263  Facebook           travel  tourism   STB      JP
# 53264  Facebook           travel  tourism   STB      JP
# 53265  Facebook           travel  tourism   STB      JP
#
#                                               Source_URL Keywords  \
# 0      https://www.facebook.com/5623675204312941_5624...     Cost
# 1      https://www.facebook.com/5623675204312941_5624...     Cost
# 2      https://www.facebook.com/5623675204312941_5623...     Cost
# 3      https://www.facebook.com/5623675204312941_5623...     Cost
# 4      https://www.facebook.com/5623675204312941_5624...     Cost
# ...                                                  ...      ...
# 53261  https://www.facebook.com/groups/nevgiv/permali...      NaN
# 53262  https://www.facebook.com/groups/nevgiv/permali...      NaN
# 53263  https://www.facebook.com/groups/nevgiv/permali...      NaN
# 53264  https://www.facebook.com/groups/nevgiv/permali...      NaN
# 53265  https://www.facebook.com/groups/nevgiv/permali...      NaN
#
#                                 post_id                         comment_id
# 0      718449554835555_5623675204312941  5623675204312941_5624525237561271
# 1      718449554835555_5623675204312941  5623675204312941_5624448567568938
# 2      718449554835555_5623675204312941  5623675204312941_5623899034290558
# 3      718449554835555_5623675204312941  5623675204312941_5623717320975396
# 4      718449554835555_5623675204312941  5623675204312941_5624220420925086
# ...                                 ...                                ...
# 53261                               NaN                                NaN
# 53262                               NaN                                NaN
# 53263                               NaN                                NaN
# 53264                               NaN                                NaN
# 53265                               NaN                                NaN
#
# [53266 rows x 18 columns]

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
# Empty DataFrame
# Columns: [User, User_loc, Date, Discussion, Discussion_translated, Hashtag, Source_title, Type, User_profile, Source, Product_category, Product, Brand, Country, Source_URL, Keywords, post_id, comment_id]
# Index: []

# %%
comments_master.dtypes
# Out:
# User                     object
# User_loc                 object
# Date                     object
# Discussion               object
# Discussion_translated    object
# Hashtag                  object
# Source_title             object
# Type                     object
# User_profile             object
# Source                   object
# Product_category         object
# Product                  object
# Brand                    object
# Country                  object
# Source_URL               object
# Keywords                 object
# post_id                  object
# comment_id               object
# dtype: object

# %%
#only select comments made in 2021
comments_master = comments_master[comments_master['Date'].str.contains('2021')]

#drop automated comments
comments_master = comments_master[~comments_master['Discussion'].str.contains('Message from Tripadvisor staff')]

comments_master
# Out:
#        User User_loc                 Date  \
# 0      none       UK  2021-03-05 07:21:10
# 1      none       UK  2021-03-05 06:52:48
# 2      none       UK  2021-03-05 03:43:05
# 3      none       UK  2021-03-05 02:43:19
# 4      none       UK  2021-03-05 05:36:27
# ...     ...      ...                  ...
# 53244  none       JP  2021-05-23 00:00:00
# 53245  none       JP  2021-07-01 00:00:00
# 53250  none       JP  2021-07-16 00:00:00
# 53255  none       JP  2021-07-14 00:00:00
# 53257  none       JP  2021-07-13 00:00:00
#
#                                               Discussion  \
# 0           Go smash 💥 it 👌 with plenty of good vibes 😎
# 1      Good luck, Mexico 🇲🇽 is one of my favourite pl...
# 2      Blame covid !!! Everyone else is for everythin...
# 3      You look so serene, i sure all that positive e...
# 4                                            Suerte!! 🤞🏻
# ...                                                  ...
# 53244  テアトロ、オリンピコには、何回か入りました。これから音楽祭が楽しみですね。素晴らしい劇場で、...
# 53245             このスティギョーラ屋さんはNHK・Ｅテレの旅するイタリア語で見ました。✌😁✌
# 53250             湖畔に有る「善き羊飼いの教会」は、天の川銀河の撮影ポイントとして有名ですね😃
# 53255                     え～っ凄い😲‼️、まるで映画でも観ているみたいです～🤩🎉‼️
# 53257                 お勧めありがとうございます。流行が好転したら日本へ旅行に来てください
#
#                                    Discussion_translated Hashtag  \
# 0           Go smash 💥 it 👌 with plenty of good vibes 😎      NaN
# 1      Good luck, Mexico 🇲🇽 is one of my favourite pl...     NaN
# 2      Blame covid !!! Everyone else is for everythin...     NaN
# 3      You look so serene, i sure all that positive e...     NaN
# 4                                            Suerte!! 🤞🏻     NaN
# ...                                                  ...     ...
# 53244  I';ve been to the Teatro and Olympics several ...     NaN
# 53245  I saw this stigola shop in the traveling Itali...     NaN
# 53250  The &quot;Church of the Good Shepherd&quot; on...     NaN
# 53255  Eh ~ amazing 😲‼ ️, It';s like watching a movie...     NaN
# 53257  Thank you for your recommendation. Please come...     NaN
#
#                   Source_title          Type User_profile    Source  \
# 0                Becs Cronshaw  social media         none  Facebook
# 1                Becs Cronshaw  social media         none  Facebook
# 2                Becs Cronshaw  social media         none  Facebook
# 3                Becs Cronshaw  social media         none  Facebook
# 4                Becs Cronshaw  social media         none  Facebook
# ...                        ...           ...          ...       ...
# 53244  イタリア好き委員会　イタリア旅行情報交換ボード  social media         none  Facebook
# 53245  イタリア好き委員会　イタリア旅行情報交換ボード  social media         none  Facebook
# 53250             旅行大好き（国内、海外）  social media         none  Facebook
# 53255             旅行大好き（国内、海外）  social media         none  Facebook
# 53257             旅行大好き（国内、海外）  social media         none  Facebook
#
#       Product_category  Product Brand Country  \
# 0               travel  tourism   STB      UK
# 1               travel  tourism   STB      UK
# 2               travel  tourism   STB      UK
# 3               travel  tourism   STB      UK
# 4               travel  tourism   STB      UK
# ...                ...      ...   ...     ...
# 53244           travel  tourism   STB      JP
# 53245           travel  tourism   STB      JP
# 53250           travel  tourism   STB      JP
# 53255           travel  tourism   STB      JP
# 53257           travel  tourism   STB      JP
#
#                                               Source_URL Keywords  \
# 0      https://www.facebook.com/5623675204312941_5624...     Cost
# 1      https://www.facebook.com/5623675204312941_5624...     Cost
# 2      https://www.facebook.com/5623675204312941_5623...     Cost
# 3      https://www.facebook.com/5623675204312941_5623...     Cost
# 4      https://www.facebook.com/5623675204312941_5624...     Cost
# ...                                                  ...      ...
# 53244  https://www.facebook.com/groups/itzliazuki/per...      NaN
# 53245  https://www.facebook.com/groups/itzliazuki/per...      NaN
# 53250  https://www.facebook.com/groups/19913320737501...      NaN
# 53255  https://www.facebook.com/groups/19913320737501...      NaN
# 53257  https://www.facebook.com/groups/19913320737501...      NaN
#
#                                 post_id                         comment_id
# 0      718449554835555_5623675204312941  5623675204312941_5624525237561271
# 1      718449554835555_5623675204312941  5623675204312941_5624448567568938
# 2      718449554835555_5623675204312941  5623675204312941_5623899034290558
# 3      718449554835555_5623675204312941  5623675204312941_5623717320975396
# 4      718449554835555_5623675204312941  5623675204312941_5624220420925086
# ...                                 ...                                ...
# 53244                               NaN                                NaN
# 53245                               NaN                                NaN
# 53250                               NaN                                NaN
# 53255                               NaN                                NaN
# 53257                               NaN                                NaN
#
# [42081 rows x 18 columns]

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/STB_GTT_Step1Output/Facebook.csv",index=False)
