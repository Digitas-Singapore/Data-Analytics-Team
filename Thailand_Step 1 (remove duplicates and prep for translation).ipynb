# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

os.chdir("/Users/chrtjen/Desktop/STB_GTT/Thailand")

# %%
filenames = os.listdir()

dfs = []
df_names = []
for filename in filenames:
    if 'csv' in filename:
        df_names.append(filename)
        dfs.append(pd.read_csv(filename))
  
print(f'read the following dataframes: {df_names}')
# Out:
# read the following dataframes: ['LostwalletinChiangMai.csv', 'TransitfordifferentPNRatSuvarnabhumiBangkok.csv', 'TripsexcursionsfromPhangNga.csv', 'TaxifromLaemchabang.csv', 'Junglekitchen.csv', 'Airporttransferat5amfromKrabiTownandaoNang.csv', 'Quiteisharea.csv', 'PKKtoChumphonbytrain.csv', 'GuideinChiangRai.csv', 'MuKoChumphonNationalMarinePark.csv', 'GeneralPostOfficeCharoenKrongRoad.csv', 'PossibletogetFromChiangMaitoMaeHongSonin1Day.csv', 'Carbs.csv', 'Wheretostayfor1night.csv', 'DriverforafamilywiththreechildrenOctober2016.csv', 'DIYDayTripfromPhuketKhaoLak.csv', 'FInalizedItineraryAnyglaringpacingtravelproblems.csv', 'Taxiquestion.csv', 'IsthereaNationalParkFeeScaminAoNang.csv', 'WasnttoosurewheretopostthisKrabiorKhaoLakForum.csv', 'TouringBangkoksolo.csv', 'DoraemoninThailand.csv', 'KohLipetoTarutaoinMay.csv', 'Liveblues.csv', 'SalaPhuketbeachmassage.csv', 'UTapaoAirporttoKohSamet.csv', 'Firstsolointernationaltripneedhelp.csv', 'Suggestionsfor4starpropertieswithin3000INR.csv', 'VisaRunChiangRaitoMaeSaiFeb2020USpassport.csv', 'ThailandorIndonesiainAugust.csv', 'fishingKoSamui.csv', 'MoraceabyKhaoLak.csv', 'IsitworthtovisitKoNgaiinmidOctobertoorainy.csv', 'Currentexchangeratesinkhaolak.csv', 'PhuketLateOctoberSwimming.csv', 'Gettingfrompiertobophutfishermansvillagecosts.csv', 'FirsttimeThailandhelp.csv', 'Sensimartransfers.csv', 'MukrathaMookatainBangkok.csv', 'Critiquemytimeline.csv', 'Isklookreliablelegitimate.csv', 'Phuketwhatisthesituation.csv', 'Taxisspeedboatscarrentals.csv', 'PartyinPhuket.csv', 'Sooverwhelmedbyallthehoteloptions.csv', 'Suggestionsona2weektriparoundChristmas2017.csv', 'Panvimanairportshuttlecost.csv', 'InternationaltoInternationalTransferatSuvarnabhumi.csv', 'PhuketInternationalExchangeBooths.csv', 'movenpickhotelpattaya.csv', 'Cellphonecarrierandpackagequestion.csv', 'LookingforVietnamwasvetswhowhereatUdornRTAFB.csv', 'Averagetaxifares.csv', 'MustseethingstodoinPattaya.csv', 'AngthongParktourwithoutsnorkellingkayaking.csv', 'Howcanigettransitvisaforthailand.csv', 'TrackingyouTrainSRT.csv', 'LaserSurgeryforEyes.csv', 'TaxifromSoi18toairport.csv', 'Whichislandtodive.csv', 'DonMuangAirportLeftLuggage.csv', 'EarlyMorning.csv', 'BudgetforamonthinThailandpleasee.csv', 'Treatmentfordepression.csv', 'ReliableandhonestBangkoktaxidriver.csv', 'AddingNokAirFlynFerrytoKohPhangangafterbooking.csv', 'BookatourfromEnglandorwaittillinPhuket.csv', 'WheretostayinChiangMaiThingsweMUSTdo.csv', 'BKKairporttoSukhothaiandAyuttaya.csv', 'wheretostayAonangorRailay.csv', 'ShouldIgoeastorwestofChiangMai.csv', 'Jailor50000THBfinefordrivingwithoutalicence.csv', 'Wheretogetacakeforabacheloretteparty.csv', 'TriptoPhuketneedideaslocations.csv', 'StormPabuk.csv', 'BangkoktoHuaHinbyair.csv', 'Sharedminivan.csv', 'PayingHotels.csv', 'VisaStampissue.csv', 'taxivsshuttleandchangingflights.csv', 'Anyonehelpwithflodonplease.csv', 'ToddlerinBKK.csv', 'Revolutcards.csv', 'RhinoplastyThailand.csv', 'Currencychange.csv', 'TimingforVOAtransferfromBKKcheckinhotel.csv', 'NoSundayWalkingStreetonAug72016.csv', 'ArtpaintingclassinPhuket.csv', 'TransfersfromPhuketairporttoPhiPhiislandswithbags.csv', 'ComparisonbetweenOceanworldandmarinepark.csv', 'storageofluggage.csv', 'AnantaraRiversideResortprosandcons.csv', 'WheretoextendmyVisafrom30daysto90days.csv', 'IcannottraveldirecttoThailandfromUSAmybloodpressu.csv', 'TripPlanAdvise.csv', 'chatuchakmarketsomuchchange.csv', 'XmasNewYearKrabiBangkokKanchanaburithenSriLanka.csv', 'ShoppingfromWater.csv', 'WatersinNovtoPhiPhiIsland.csv', 'Newyear.csv', 'PhuketsightseeingtraveloptionsduringChristmas.csv', 'AirAsiatoPhuket.csv', 'KoMaktoSiemReapDecember.csv', 'Kohphanganopenornot.csv', 'PatongtoKohTao.csv', 'costoftaxifromtheairporttokata.csv', 'PleaserecommendluxuryhotelsinBangkokandChiangMai.csv', 'WhatareatostayinPhuket.csv', 'SpendingmoneyforBangkokandSingapore.csv', 'WendyWuThailandTours.csv', 'JuicesinBars.csv', 'Suggestagoodhotelonniceplace.csv', 'ArepriceslikelytofallforFebruary.csv', 'PhuketSuggest ...

# %%
#create the master dataframe

comments_master = pd.concat(dfs, ignore_index=True, sort=False).dropna(subset=['Discussion']).reset_index(drop=True)
comments_master
# Out:
#                       User                        User_loc         Date  \
# 0            Willy-Phoenix                             NaN  4 years ago
# 1             sweetpea6468                           perth  4 years ago
# 2                   bill2p                 Berlin, Germany  4 years ago
# 3       Kevin_One_Man_Show                Kenmare, Ireland  4 years ago
# 4                      NaN  Surat Thani Province, Thailand  3 years ago
# ...                    ...                             ...          ...
# 554921    malabar-coasters                           Hanoi  2 years ago
# 554922                 NaN                  Thailand, Asia   1 year ago
# 554923        geordiebloke                             NaN  2 years ago
# 554924             DIKTHAI               Bangkok, Thailand  2 years ago
# 554925                 NaN    Phang Nga Province, Thailand   1 year ago
#
#                                                Discussion Hashtag  \
# 0       I just lost my wallet this morning, possibly i...     NaN
# 1       Hi\nFirstly report this to police. You will ne...     NaN
# 2       I would get a Thai to help you, maybe a fellow...     NaN
# 3                    That is great advice Bill!\nNice one     NaN
# 4       -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# ...                                                   ...     ...
# 554921  Watch that the ink is what you want...not phot...     NaN
# 554922  -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 554923  Hi everyone..\nWe are travelling to Phuket in ...     NaN
# 554924  Child trafficking in SE Asia is a very big pro...     NaN
# 554925  -:- Message from Tripadvisor staff -:-\nThis t...     NaN
#
#                          Source_title   Type  \
# 0           Lost wallet in Chiang Mai  forum
# 1           Lost wallet in Chiang Mai  forum
# 2           Lost wallet in Chiang Mai  forum
# 3           Lost wallet in Chiang Mai  forum
# 4                                 NaN    NaN
# ...                               ...    ...
# 554921         Reputable tattoo shops  forum
# 554922                            NaN    NaN
# 554923  Babysitter or Nanny in Phuket  forum
# 554924  Babysitter or Nanny in Phuket  forum
# 554925                            NaN    NaN
#
#                                              User_profile       Source  \
# 0       https://www.tripadvisor.com/Profile/Willy-Phoe...  tripadvisor
# 1       https://www.tripadvisor.com/Profile/sweetpea64...  tripadvisor
# 2       https://www.tripadvisor.com/Profile/bill2p?tab...  tripadvisor
# 3       https://www.tripadvisor.com/Profile/Kevin_One_...  tripadvisor
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 554921  https://www.tripadvisor.com/Profile/malabar-co...  tripadvisor
# 554922                                                NaN          NaN
# 554923  https://www.tripadvisor.com/Profile/geordieblo...  tripadvisor
# 554924  https://www.tripadvisor.com/Profile/DIKTHAI?ta...  tripadvisor
# 554925                                                NaN          NaN
#
#        Product_category  Product Brand Country  \
# 0                travel  tourism   stb      th
# 1                travel  tourism   stb      th
# 2                travel  tourism   stb      th
# 3                travel  tourism   stb      th
# 4                   NaN      NaN   NaN     NaN
# ...                 ...      ...   ...     ...
# 554921           travel  tourism   stb      th
# 554922              NaN      NaN   NaN     NaN
# 554923           travel  tourism   stb      th
# 554924           travel  tourism   stb      th
# 554925              NaN      NaN   NaN     NaN
#
#                                                Source_URL
# 0       https://www.tripadvisor.com/ShowTopic-g293915-...
# 1       https://www.tripadvisor.com/ShowTopic-g293915-...
# 2       https://www.tripadvisor.com/ShowTopic-g293915-...
# 3       https://www.tripadvisor.com/ShowTopic-g293915-...
# 4                                                     NaN
# ...                                                   ...
# 554921  https://www.tripadvisor.com/ShowTopic-g580110-...
# 554922                                                NaN
# 554923  https://www.tripadvisor.com/ShowTopic-g293920-...
# 554924  https://www.tripadvisor.com/ShowTopic-g293920-...
# 554925                                                NaN
#
# [554926 rows x 14 columns]

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
#        User                       User_loc         Date  \
# 1515    NaN  Chiang Mai Province, Thailand   1 year ago
# 1709    NaN   Phang Nga Province, Thailand   1 year ago
# 1770    NaN                 Thailand, Asia  4 years ago
# 1837    NaN                 Thailand, Asia  4 years ago
# 2144    NaN                           Asia  2 years ago
# ...     ...                            ...          ...
# 554881  NaN                 Thailand, Asia  2 years ago
# 554886  NaN                           Asia  2 years ago
# 554903  NaN   Phang Nga Province, Thailand  2 years ago
# 554907  NaN  Chiang Mai Province, Thailand  3 years ago
# 554922  NaN                 Thailand, Asia   1 year ago
#
#                                                Discussion Hashtag  \
# 1515    -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 1709    -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 1770    -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 1837    -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 2144    -:- Message from Tripadvisor staff -:-\nTripad...     NaN
# ...                                                   ...     ...
# 554881  -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 554886  -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 554903  -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 554907  -:- Message from Tripadvisor staff -:-\nThis t...     NaN
# 554922  -:- Message from Tripadvisor staff -:-\nThis t...     NaN
#
#        Source_title Type User_profile Source Product_category Product Brand  \
# 1515            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 1709            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 1770            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 1837            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 2144            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# ...             ...  ...          ...    ...              ...     ...   ...
# 554881          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 554886          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 554903          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 554907          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 554922          NaN  NaN          NaN    NaN              NaN     NaN   NaN
#
#        Country Source_URL
# 1515       NaN        NaN
# 1709       NaN        NaN
# 1770       NaN        NaN
# 1837       NaN        NaN
# 2144       NaN        NaN
# ...        ...        ...
# 554881     NaN        NaN
# 554886     NaN        NaN
# 554903     NaN        NaN
# 554907     NaN        NaN
# 554922     NaN        NaN
#
# [27832 rows x 14 columns]

# %%
comments_master.dtypes
# Out:
# User                object
# User_loc            object
# Date                object
# Discussion          object
# Hashtag             object
# Source_title        object
# Type                object
# User_profile        object
# Source              object
# Product_category    object
# Product             object
# Brand               object
# Country             object
# Source_URL          object
# dtype: object

# %%
#only select comments made in 2021
comments_master = comments_master[comments_master['Date'].str.contains('2021')]

#drop automated comments
comments_master = comments_master[~comments_master['Discussion'].str.contains('Message from Tripadvisor staff')]

comments_master
# Out:
#                      User                User_loc                    Date  \
# 43       theparkiesjersey       jersey channel...    Jan 7, 2021, 3:13 PM
# 44               KhunBill         Loughborough...    Jan 7, 2021, 3:33 PM
# 45            lordkimmage        County Dublin...    Jan 7, 2021, 6:31 PM
# 46       Life's a Beach ⛱                     NaN    Jan 7, 2021, 9:22 PM
# 47      ThaiThaiblackbird  South Devon, United...    Jan 8, 2021, 8:56 AM
# ...                   ...                     ...                     ...
# 554713   IrelandIrisheyes        County Dublin...   May 10, 2021, 6:24 AM
# 554714   IrelandIrisheyes         Dublin, Ireland   May 10, 2021, 6:26 AM
# 554716            j0n0339         Dublin, Ireland   May 14, 2021, 8:54 AM
# 554717   IrelandIrisheyes         Dublin, Ireland  May 14, 2021, 12:33 PM
# 554718                NaN                    Asia  May 15, 2021, 10:48 AM
#
#                                                Discussion Hashtag  \
# 43      Hi all,\nPlanning a trip to Ko Yao Noi ????? N...     NaN
# 44      Nai Yang would suit you. Have a look. Quiet, n...     NaN
# 45      Kamala would give you laid-back and quiet. And...     NaN
# 46      Phuket and most of Thailand will be laid back,...     NaN
# 47      Back on topic......\n+1 for Nai Yang - my favo...     NaN
# ...                                                   ...     ...
# 554713  Thanks CharlesR. I have been checking the area...     NaN
# 554714       Actually meant Karon Sea Sands Resort hotel.     NaN
# 554716  We're a mature couple traveling to Karon in Fe...     NaN
# 554717  +1 for Beyond resort.Stayed there a couple of ...     NaN
# 554718    Thanks to all. All suggestions are appreciated.     NaN
#
#                      Source_title   Type  \
# 43             Quite ish area....  forum
# 44             Quite ish area....  forum
# 45             Quite ish area....  forum
# 46             Quite ish area....  forum
# 47             Quite ish area....  forum
# ...                           ...    ...
# 554713  Choosing a hotel in Karon  forum
# 554714  Choosing a hotel in Karon  forum
# 554716  Choosing a hotel in Karon  forum
# 554717  Choosing a hotel in Karon  forum
# 554718                        NaN    NaN
#
#                                              User_profile       Source  \
# 43      https://www.tripadvisor.com/Profile/theparkies...  tripadvisor
# 44      https://www.tripadvisor.com/Profile/KhunBill?t...  tripadvisor
# 45      https://www.tripadvisor.com/Profile/lordkimmag...  tripadvisor
# 46      https://www.tripadvisor.com/Profile/UP2UorNot?...  tripadvisor
# 47      https://www.tripadvisor.com/Profile/ThaiThaibl...  tripadvisor
# ...                                                   ...          ...
# 554713  https://www.tripadvisor.com/Profile/IrelandIri...  tripadvisor
# 554714  https://www.tripadvisor.com/Profile/IrelandIri...  tripadvisor
# 554716  https://www.tripadvisor.com/Profile/j0n0339?ta...  tripadvisor
# 554717  https://www.tripadvisor.com/Profile/IrelandIri...  tripadvisor
# 554718                                                NaN          NaN
#
#        Product_category  Product Brand Country  \
# 43               travel  tourism   stb      th
# 44               travel  tourism   stb      th
# 45               travel  tourism   stb      th
# 46               travel  tourism   stb      th
# 47               travel  tourism   stb      th
# ...                 ...      ...   ...     ...
# 554713           travel  tourism   stb      th
# 554714           travel  tourism   stb      th
# 554716           travel  tourism   stb      th
# 554717           travel  tourism   stb      th
# 554718              NaN      NaN   NaN     NaN
#
#                                                Source_URL
# 43      https://www.tripadvisor.com/ShowTopic-g293920-...
# 44      https://www.tripadvisor.com/ShowTopic-g293920-...
# 45      https://www.tripadvisor.com/ShowTopic-g293920-...
# 46      https://www.tripadvisor.com/ShowTopic-g293920-...
# 47      https://www.tripadvisor.com/ShowTopic-g293920-...
# ...                                                   ...
# 554713  https://www.tripadvisor.com/ShowTopic-g1080471...
# 554714  https://www.tripadvisor.com/ShowTopic-g1080471...
# 554716  https://www.tripadvisor.com/ShowTopic-g1080471...
# 554717  https://www.tripadvisor.com/ShowTopic-g1080471...
# 554718                                                NaN
#
# [7476 rows x 14 columns]

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/STB_GTT_Step1Output/Thailand.csv",index=False)
