# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

os.chdir("/Users/chrtjen/Desktop/STB_GTT/United Kingdom")

# %%
filenames = os.listdir()

dfs = []
df_names = []
for filename in filenames:
    if 'csv' in filename:
        df_names.append(filename)
        dfs.append(pd.read_csv(filename))
  
print(f'read the following dataframes: {df_names}')
# Out:
# read the following dataframes: ['LastdayofourholidaynearWhitbytomorrow.csv', 'NewSouthgate.csv', '1stvisitfor4daysAmblesideKeswickbothorneither.csv', 'accommodationincarmarthen.csv', 'Heathrowflighttransfer.csv', 'anightinParis.csv', 'TransportcostsandroutesinLondon.csv', 'carbootsite.csv', 'reBlackpool.csv', 'Specific241cardquestion.csv', 'WeekendinYork.csv', 'Smallweddingreception.csv', '2for1NationalRail.csv', 'ThingstodowithKids.csv', 'SuggestedCornwallitinerary7daystwodesitinations.csv', 'PurpleParkingHeathrow.csv', 'questiononconnectingflightseasyjetstanstedto.csv', '2daysineitherBelfastorDublin.csv', 'Taxiquestion.csv', 'heathrowhotelspleasehelp.csv', 'Busservce.csv', '1sttriptoWales.csv', 'GlasgowwithKids.csv', 'wildinscotlandtouroperator.csv', '14nightsitinerarypleasehelp.csv', 'HotelsnearHiltonLondonMetropole225EdgwareRoad.csv', 'LondonWeatheronEarlyNovember.csv', 'Whichtravelpasstopurchase.csv', 'NicebeergardentowncentreneartoDeansgate.csv', 'bignightoutonthetown.csv', 'Cirencesterswindon.csv', 'FromLondontoAmsterdam.csv', 'DiscoverDogsEarlsCourt.csv', 'apartmentcheckplease.csv', 'FamilyvisitinAugustideasforactivities.csv', 'websiteforressies.csv', '5people3dogswithapool.csv', 'NicehotelingoodlocationinLondon.csv', 'SpringvisittoLondon.csv', 'WeatherForecastwhichone.csv', 'privatedinningvenuesforsmallwedding.csv', 'areabetweenInvernessandFortWilliam.csv', '3daysintheCotswoldsMUSTSEEPLACES.csv', 'Ticketswalksandquestions.csv', 'LionsandTigersandBearsOhMy.csv', 'EarlsCourtTubeorCharringCrossTube.csv', 'ATMinsideLondonBank.csv', 'Celticgame.csv', 'StairwiseVictoriaorStJamessUnderground.csv', 'AntiqueMarketsduringXmas.csv', 'cheapesttransportationtoDCfromBaltimore.csv', 'bookinginadvancefortennerfest.csv', 'TravelfromSouthamptonCruisePorttoLondon.csv', 'Bournemouthtrip.csv', 'BestplacetoseeHadriansWall.csv', 'BeefinLondon.csv', 'LondonWestend.csv', 'NorthorSouthterminalforVuelingAiroutofGatwick.csv', 'IsthereagoodcentralbookingsiteforhotelsinScotland.csv', 'AnnualTriptoManchesterNFMac.csv', 'WeatherspoonPub.csv', 'AgendaHotelstillthere.csv', 'HasanyoneelsedealtwithMagicRentalsLondon.csv', 'SaturdayTowerBridgeTOlorCamdenMarketBritishMuseum.csv', 'ExcessCarRentalInsurance.csv', 'Londontripwithtwogirlsaged10and12.csv', 'Museum.csv', 'GlasgowtoDrymen.csv', 'junehenpartyinBirminghamwheretogo.csv', 'Scotlanditineraryplacestostay.csv', 'Bestareatostayfor2days.csv', 'Luxuryapartment.csv', 'BarclaysbankatminLHR.csv', 'Wheretostayselfcatering.csv', 'ShorttimestayinBirminghaam.csv', 'MillenniumGloucesterMillKnightsbridgeorHIKensFor.csv', 'firsttriptoEurope.csv', 'OrmeSummitComplexBAD.csv', 'oystercardtravelcardneedadvice.csv', 'ObanKennacraig.csv', 'HeathrowtoOxfordCircuswithababy.csv', 'BestEastertimemusicandchurchservices.csv', 'neighborhhodstoavoid.csv', 'VATonRestaurantMeals.csv', 'TourInfoRecommendationsofUnstShetlandfromLerwick.csv', 'yourfirstimpressionoflondon.csv', 'Luggagestorageinorneartrainstation.csv', 'MammaMiaseats.csv', 'BestwalkingtourofundergroundEdinburgh.csv', 'Maintrainstation.csv', 'YorkandLondonTripReportNewYears2012.csv', 'ChampionsDayNewMarketRaces.csv', 'WalkingRoutes.csv', 'TraintravelLondonEdinburghcompanyclass.csv', 'CausewayCoastalWay.csv', 'KnightsbridgeAreatoMuswellHillArea.csv', 'ShouldIstaynearStPancrasstation.csv', 'bristolairport.csv', 'LondonAndazorTheWestbridgeabetteroption.csv', 'wwwcitybudgetapartments890mcomtoogoodtobetrue.csv', 'ShortbreakfromtheUK.csv', '241travelcardwestdrayton.csv', 'SwiftAirportParkingthroughFHR.csv', 'gatwicktotudorcourthotel.csv', 'WhatshouldwedoSuggestions.csv', 'uhoh.csv', 'Newyear.csv', 'MinimoonwithpoochinCockermouth.csv', 'WalkingAROUNDtheoldcourseonanonSUNDAY.csv', 'Hammersmith.csv', 'AdviceCommentsonItinerary.csv', 'Nightoutliverpool.csv', 'CampinginCotswolds.csv', 'Rentabikewithouttour.csv', 'Travelcardoptions.csv', 'HowtogetfromLiverpoolAirporttoLiverpoolSouthwayStat.csv', 'onedaytriptoLondon.csv', 'Pkgdteaandcoffee.csv', 'EasterinGlasgow.csv', 'FlyingAerLin ...

# %%
#create the master dataframe

comments_master = pd.concat(dfs, ignore_index=True, sort=False).dropna(subset=['Discussion']).reset_index(drop=True)
comments_master
# Out:
#               User              User_loc         Date  \
# 0         Hannah M    Suffolk, United...  4 years ago
# 1            Joe G  York, United Kingdom  4 years ago
# 2         FatChris     London, United...  4 years ago
# 3          Morgana    Yorkshire Dales...  4 years ago
# 4         Hannah M    Suffolk, United...  4 years ago
# ...            ...                   ...          ...
# 648409  Auld Jimmy     London, United...  6 years ago
# 648410   wirewiper    Torquay, United...  6 years ago
# 648411      Leagle     London, United...  6 years ago
# 648412   Richard T     Harrow, United...  6 years ago
# 648413         NaN                Europe  5 years ago
#
#                                                Discussion  Hashtag  \
# 0       If you only had one day of your holiday left w...      NaN
# 1                             Robin Hoods Bay or Staithes      NaN
# 2                                       Robin Hood's Bay.      NaN
# 3       Very difficult to answer as I don't know what ...      NaN
# 4       I was hoping something someone else would say ...      NaN
# ...                                                   ...      ...
# 648409         Travelodge Gatwick.\nhttps://goo.gl/bALB7e      NaN
# 648410  Premier Inn Gatwick North it is then.\nhttp://...      NaN
# 648411  I believe the Yotel is actually in Gatwick Air...      NaN
# 648412  Easy to get to gatwick from wembley if you go ...      NaN
# 648413  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#                                              Source_title   Type  \
# 0       Last day of our holiday (near Whitby) tomorrow...  forum
# 1       Last day of our holiday (near Whitby) tomorrow...  forum
# 2       Last day of our holiday (near Whitby) tomorrow...  forum
# 3       Last day of our holiday (near Whitby) tomorrow...  forum
# 4       Last day of our holiday (near Whitby) tomorrow...  forum
# ...                                                   ...    ...
# 648409                        Help with somewhere to stay  forum
# 648410                        Help with somewhere to stay  forum
# 648411                        Help with somewhere to stay  forum
# 648412                        Help with somewhere to stay  forum
# 648413                                                NaN    NaN
#
#                                              User_profile       Source  \
# 0       https://www.tripadvisor.com/Profile/hannahm206...  tripadvisor
# 1       https://www.tripadvisor.com/Profile/joegH9058H...  tripadvisor
# 2       https://www.tripadvisor.com/Profile/FatChris?t...  tripadvisor
# 3       https://www.tripadvisor.com/Profile/Morgana?ta...  tripadvisor
# 4       https://www.tripadvisor.com/Profile/hannahm206...  tripadvisor
# ...                                                   ...          ...
# 648409  https://www.tripadvisor.com/Profile/AuldJimmy?...  tripadvisor
# 648410  https://www.tripadvisor.com/Profile/wirewiper?...  tripadvisor
# 648411  https://www.tripadvisor.com/Profile/Leagle?tab...  tripadvisor
# 648412  https://www.tripadvisor.com/Profile/richt71?ta...  tripadvisor
# 648413                                                NaN          NaN
#
#        Product_category  Product Brand Country  \
# 0                travel  tourism   stb      uk
# 1                travel  tourism   stb      uk
# 2                travel  tourism   stb      uk
# 3                travel  tourism   stb      uk
# 4                travel  tourism   stb      uk
# ...                 ...      ...   ...     ...
# 648409           travel  tourism   stb      uk
# 648410           travel  tourism   stb      uk
# 648411           travel  tourism   stb      uk
# 648412           travel  tourism   stb      uk
# 648413              NaN      NaN   NaN     NaN
#
#                                                Source_URL
# 0       https://www.tripadvisor.com/ShowTopic-g1526974...
# 1       https://www.tripadvisor.com/ShowTopic-g1526974...
# 2       https://www.tripadvisor.com/ShowTopic-g1526974...
# 3       https://www.tripadvisor.com/ShowTopic-g1526974...
# 4       https://www.tripadvisor.com/ShowTopic-g1526974...
# ...                                                   ...
# 648409  https://www.tripadvisor.com/ShowTopic-g186338-...
# 648410  https://www.tripadvisor.com/ShowTopic-g186338-...
# 648411  https://www.tripadvisor.com/ShowTopic-g186338-...
# 648412  https://www.tripadvisor.com/ShowTopic-g186338-...
# 648413                                                NaN
#
# [648414 rows x 14 columns]

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
#        User                      User_loc                   Date  \
# 5883    NaN                   England, UK            6 years ago
# 7756    NaN                   England, UK            4 years ago
# 14254   NaN  Scottish Highlands, Scotland           11 years ago
# 14877   NaN                   England, UK            4 years ago
# 21764   NaN                        Europe  Jul 1, 2021, 12:41 AM
# ...     ...                           ...                    ...
# 648017  NaN                   England, UK            8 years ago
# 648073  NaN                   England, UK            7 years ago
# 648227  NaN                   England, UK            8 years ago
# 648252  NaN                  Scotland, UK           11 years ago
# 648302  NaN                   England, UK           10 years ago
#
#                                                Discussion  Hashtag  \
# 5883    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 7756    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 14254   -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 14877   -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 21764   -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# ...                                                   ...      ...
# 648017  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 648073  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 648227  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 648252  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 648302  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#        Source_title Type User_profile Source Product_category Product Brand  \
# 5883            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 7756            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 14254           NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 14877           NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 21764           NaN  NaN          NaN    NaN              NaN     NaN   NaN
# ...             ...  ...          ...    ...              ...     ...   ...
# 648017          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 648073          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 648227          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 648252          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 648302          NaN  NaN          NaN    NaN              NaN     NaN   NaN
#
#        Country Source_URL
# 5883       NaN        NaN
# 7756       NaN        NaN
# 14254      NaN        NaN
# 14877      NaN        NaN
# 21764      NaN        NaN
# ...        ...        ...
# 648017     NaN        NaN
# 648073     NaN        NaN
# 648227     NaN        NaN
# 648252     NaN        NaN
# 648302     NaN        NaN
#
# [4398 rows x 14 columns]

# %%
comments_master.dtypes
# Out:
# User                 object
# User_loc             object
# Date                 object
# Discussion           object
# Hashtag             float64
# Source_title         object
# Type                 object
# User_profile         object
# Source               object
# Product_category     object
# Product              object
# Brand                object
# Country              object
# Source_URL           object
# dtype: object

# %%
#only select comments made in 2021
comments_master = comments_master[comments_master['Date'].str.contains('2021')]

#drop automated comments
comments_master = comments_master[~comments_master['Discussion'].str.contains('Message from Tripadvisor staff')]

comments_master
# Out:
#                User              User_loc                    Date  \
# 1929        David W     Fuengirola, Spain   Aug 4, 2021, 12:27 PM
# 1930    PMQuestions    North Yorkshire...   Aug 4, 2021, 12:35 PM
# 2715         Riaz T     Woodford Green...   Aug 27, 2021, 7:18 PM
# 2716        Barry H  Stockport, United...   Aug 28, 2021, 4:06 AM
# 2717          EESW1       Lincolnshire...   Aug 28, 2021, 4:31 AM
# ...             ...                   ...                     ...
# 646590   tjgfitness   Plymouth, United...   Aug 20, 2021, 2:53 PM
# 646591     RojBlake      Wales, United...   Aug 21, 2021, 3:40 PM
# 646592      SpotBoy        United Kingdom   Aug 21, 2021, 4:58 PM
# 646593   tjgfitness   Plymouth, United...  Aug 21, 2021, 10:52 PM
# 646594    CymraesUn                 Wales  Aug 24, 2021, 10:23 AM
#
#                                                Discussion  Hashtag  \
# 1929    Returning to the UK later this month from Spai...      NaN
# 1930    Well currently you need one before you leave S...      NaN
# 2715    Hi, I’m going to visit leith my 3 kids, please...      NaN
# 2716    In terms of things to do going on the Great Or...      NaN
# 2717    They may also enjoy the Great Orme Copper mine...      NaN
# ...                                                   ...      ...
# 646590  Hi..we are coming to Cardiff this weekend and ...      NaN
# 646591  I'll be honest. I don't normally drive to Card...      NaN
# 646592  Very difficult to find anything free, in and a...      NaN
# 646593            Thank you for that will try those areas      NaN
# 646594  There is plenty of parking around the Bay, but...      NaN
#
#                                            Source_title   Type  \
# 1929                                      Covid Testing  forum
# 1930                                      Covid Testing  forum
# 2715    First ever visit with 3 kids under 8 need guide  forum
# 2716    First ever visit with 3 kids under 8 need guide  forum
# 2717    First ever visit with 3 kids under 8 need guide  forum
# ...                                                 ...    ...
# 646590                    Free parking near Cardiff bay  forum
# 646591                    Free parking near Cardiff bay  forum
# 646592                    Free parking near Cardiff bay  forum
# 646593                    Free parking near Cardiff bay  forum
# 646594                    Free parking near Cardiff bay  forum
#
#                                              User_profile       Source  \
# 1929    https://www.tripadvisor.com/Profile/N6078GIdav...  tripadvisor
# 1930    https://www.tripadvisor.com/Profile/PMQuestion...  tripadvisor
# 2715    https://www.tripadvisor.com/Profile/588riazt?t...  tripadvisor
# 2716    https://www.tripadvisor.com/Profile/bazonian20...  tripadvisor
# 2717    https://www.tripadvisor.com/Profile/EESW1?tab=...  tripadvisor
# ...                                                   ...          ...
# 646590  https://www.tripadvisor.com/Profile/tjgfitness...  tripadvisor
# 646591  https://www.tripadvisor.com/Profile/RojBlake?t...  tripadvisor
# 646592  https://www.tripadvisor.com/Profile/SpotBoy?ta...  tripadvisor
# 646593  https://www.tripadvisor.com/Profile/tjgfitness...  tripadvisor
# 646594  https://www.tripadvisor.com/Profile/CymraesUn?...  tripadvisor
#
#        Product_category  Product Brand Country  \
# 1929             travel  tourism   stb      uk
# 1930             travel  tourism   stb      uk
# 2715             travel  tourism   stb      uk
# 2716             travel  tourism   stb      uk
# 2717             travel  tourism   stb      uk
# ...                 ...      ...   ...     ...
# 646590           travel  tourism   stb      uk
# 646591           travel  tourism   stb      uk
# 646592           travel  tourism   stb      uk
# 646593           travel  tourism   stb      uk
# 646594           travel  tourism   stb      uk
#
#                                                Source_URL
# 1929    https://www.tripadvisor.com/ShowTopic-g1842228...
# 1930    https://www.tripadvisor.com/ShowTopic-g1842228...
# 2715    https://www.tripadvisor.com/ShowTopic-g190724-...
# 2716    https://www.tripadvisor.com/ShowTopic-g190724-...
# 2717    https://www.tripadvisor.com/ShowTopic-g190724-...
# ...                                                   ...
# 646590  https://www.tripadvisor.com/ShowTopic-g186460-...
# 646591  https://www.tripadvisor.com/ShowTopic-g186460-...
# 646592  https://www.tripadvisor.com/ShowTopic-g186460-...
# 646593  https://www.tripadvisor.com/ShowTopic-g186460-...
# 646594  https://www.tripadvisor.com/ShowTopic-g186460-...
#
# [11084 rows x 14 columns]

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/STB_GTT_Step1Output/UK.csv",index=False)
