# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

os.chdir("/Users/chrtjen/Desktop/STB_GTT/Australia")

# %%
filenames = os.listdir()

dfs = []
df_names = []
for filename in filenames:
    if 'csv' in filename:
        df_names.append(filename)
        dfs.append(pd.read_csv(filename))
  
print(f'read the following dataframes: {df_names}')
# Out:
# read the following dataframes: ['NewservicedapartmentFitzroy.csv', 'Howmuchwouldataxicost.csv', 'AccommodationAvailabilitybetweenBrisbaneSydneyinJan.csv', 'SydneyHarbourFireworkseverySaturday.csv', 'Troublewithhotel.csv', '7daystripwitha3yearstoddlerinseptember.csv', 'campervanaccessibilitysitesanditinery.csv', '2nightsUluruItinerarysuggestions.csv', 'Needaselfcontainedapartmentnotsurfersorsimalar.csv', 'Crabbinganyone.csv', 'TheSanctuaryTableCape.csv', 'VisittoStraddleinNovember.csv', 'HelpthreenightsinTasfor40thbirthdayideaspls.csv', 'Mooloolaba3nightsNOVcheapcarhiretovisitNoosa.csv', 'Wheretostayfor1night.csv', 'ladyelliotgoodprice.csv', 'SebelInMarroochydore.csv', 'Shorttermapartment.csv', 'anothermessageforabbey.csv', 'Thingstodowithkids.csv', 'HowtopurchasefasttrackticketsforGoldCoastthemepark.csv', 'AliceSpringsCaravanandcampingPark.csv', 'AccommodationwhereisbestforBrisbaneEntCentre.csv', 'LookingforaFantasticXmasgiftforhim.csv', 'WhichBotanicGardenAquariumMountains.csv', 'IsSeptemberagoodseasontovisitCairns.csv', 'Afternoonsunsetsaillowislenotacharter.csv', 'SydneyTransfersJetstarArrivalTimeinSydneyfromHonolulu.csv', 'flyingintoHIbutstayinginAB.csv', 'NYEfireworksSydneyOperaHouse.csv', 'StingersNovember.csv', 'WheretobuyfreshfishinHobartarea.csv', 'Cheapbudgetsingleroom.csv', 'AlbanytoAdelaideviaNullarbor.csv', 'TailorsandSquash.csv', 'GoodpubstoeatneartheStamfordonNorthTerrace.csv', 'OnmyowninSydneywhatshouldIdo.csv', 'HowdoIgetfromtheinnercitytoDraculasCabernet.csv', 'TripReport5dayswithkidsaged1012Nov2012.csv', 'Crystalclearbluewater.csv', 'Coopersbreweryaccessiblebypublictransport.csv', 'Lookingfor1or2BedroomUnitforMardiGrasMustbeon.csv', 'MantraTrilogyCairns.csv', 'PeppersSheratonorSeaTemple.csv', 'GLinktramstopsvisuallyimpaired.csv', 'usingATMs.csv', 'TintoelaorShearwater.csv', 'OpiniononSydneyAirbnblocationMillersPoint.csv', 'Noideawheretostart.csv', 'Late20sfemaleonherown.csv', 'sydneyairporttofourseasons.csv', 'WheretoseeturtlesmidJanuary.csv', 'jetstardomestictoqantasinternationalseamlesstransfer.csv', 'SnowinMelbourne.csv', 'hirecaronferrytomagneticisland.csv', 'ChristinesCastlevacationrentalPerthAustralia.csv', '10daytrip.csv', 'MiddleEasternFood.csv', 'DivinginBrisbane.csv', 'Emirateshelp.csv', 'FamilyFriendlyNYE.csv', 'DrivefromSydneytoMelbVictoria.csv', 'BestrouteSydneyBlueMountainsGloucesterCanberra.csv', 'BestplacestoexchangemoneyEurosinAUDinMelbourne.csv', 'ListofplacesopenXmasdayinMelb.csv', 'Boseheadphones.csv', 'Whalewatchingoptionsfromtheshore.csv', 'GOR2day1NandMelbourrne1N.csv', 'BestcaravanparksalongtheMurrayinSA.csv', 'ItsmeImbackfornow.csv', 'GeelongLocalsneedadvice.csv', 'StormorCollingwood.csv', 'Simcardsmobilephone.csv', 'GreatOceanRoadupgrade.csv', 'BudgettravelAirlieBeachWhitsundays.csv', 'OutletshoppingatBrisbane.csv', 'Bestareatobein.csv', 'AccomodationTheRocks.csv', 'HotelsinAdelaide.csv', 'TravellingtimeBroomeFitzroyCrossingby4WD.csv', 'JerilderieLetterEventhowcoolisthis.csv', 'SandTobagonningandsnorkeling.csv', 'DrivingfromSouthBrisbanetotheBunyaMountains.csv', 'xmaslightsdisplay.csv', 'AnyoneknowanythingaboutaplacecalledPerenjoriWA.csv', 'DaydreamIslandReview.csv', 'Adviceneededpleasehelp.csv', 'Offseasonhirecarortours.csv', 'HamiltonIsland2009updateonadvicereapartments.csv', 'placestostayinmanly.csv', 'Adelaideandsurroundingareafor5nightswithbaby.csv', 'RecommedationonAccommodation.csv', 'PortDouglasMotelQLD.csv', 'PerthTravelOct2015help.csv', 'DutyFreeCarnivalSpirit.csv', 'stayatBallaratorGrampians.csv', 'RestaurantrecommendationsforPerthConvention.csv', 'TravelingforWhitehavenBeach.csv', 'WantedAccomwhichallowsearlycheckinof7am.csv', 'Arliebeachtocairns.csv', '6hoursattheairport.csv', 'familyfriendlyhostel4wdcarhire.csv', 'Lookingforsuggetions.csv', 'Ontheway.csv', 'nowitsfloodinginBourke.csv', 'SydneytoCairns.csv', 'The12ApostlesGOR.csv', 'Anyrecommendationsonwinerieswithaccommodation.csv', 'Brunyislandselfdriveortour.csv', 'GORornot.csv', 'GreatoceanroadschooliesGoldCoastnov2 ...

# %%
#create the master dataframe

comments_master = pd.concat(dfs, ignore_index=True, sort=False).dropna(subset=['Discussion']).reset_index(drop=True)
comments_master
# Out:
#                       User                  User_loc          Date  \
# 0             peppermint72                       NaN  12 years ago
# 1             MelbourneJab      Melbourne, Australia  12 years ago
# 2                   Will G             Strathmore...  12 years ago
# 3             peppermint72                       NaN  12 years ago
# 4                   Will G             Strathmore...  12 years ago
# ...                    ...                       ...           ...
# 636304           chloenats        Jakarta, Indonesia   6 years ago
# 636305                 NaN             South Pacific   5 years ago
# 636306  KiwiGirl_in_Aussie             Queensland...  12 years ago
# 636307  KiwiGirl_in_Aussie             Queensland...  12 years ago
# 636308                 NaN  Greater Hobart, Tasmania  11 years ago
#
#                                                Discussion  Hashtag  \
# 0       Hi\nI am looking for a place to stay in Melbou...      NaN
# 1       Hi\nFitzroy is a well established older area o...      NaN
# 2       MelbourneJab sums it up pretty nicely. This is...      NaN
# 3       Thanks for the information. It certainly helpe...      NaN
# 4                   Did you take it or go somewhere else?      NaN
# ...                                                   ...      ...
# 636304                  Thanks everyone. Appreciate it :)      NaN
# 636305  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 636306  Hi, does anyone know of a good reflexology pla...      NaN
# 636307  OK, I can answer my own question now. There is...      NaN
# 636308  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#                                       Source_title   Type  \
# 0                 New serviced apartment @ Fitzroy  forum
# 1                 New serviced apartment @ Fitzroy  forum
# 2                 New serviced apartment @ Fitzroy  forum
# 3                 New serviced apartment @ Fitzroy  forum
# 4                 New serviced apartment @ Fitzroy  forum
# ...                                            ...    ...
# 636304  Opening hours for cafe in Sydney CBD area?  forum
# 636305                                         NaN    NaN
# 636306                                 Reflexology  forum
# 636307                                 Reflexology  forum
# 636308                                         NaN    NaN
#
#                                              User_profile       Source  \
# 0       https://www.tripadvisor.com/Profile/peppermint...  tripadvisor
# 1       https://www.tripadvisor.com/Profile/MelbourneJ...  tripadvisor
# 2       https://www.tripadvisor.com/Profile/willnino?t...  tripadvisor
# 3       https://www.tripadvisor.com/Profile/peppermint...  tripadvisor
# 4       https://www.tripadvisor.com/Profile/willnino?t...  tripadvisor
# ...                                                   ...          ...
# 636304  https://www.tripadvisor.com/Profile/chloenats?...  tripadvisor
# 636305                                                NaN          NaN
# 636306  https://www.tripadvisor.com/Profile/KiwiGirl_i...  tripadvisor
# 636307  https://www.tripadvisor.com/Profile/KiwiGirl_i...  tripadvisor
# 636308                                                NaN          NaN
#
#        Product_category  Product Brand Country  \
# 0                travel  tourism   stb      hk
# 1                travel  tourism   stb      hk
# 2                travel  tourism   stb      hk
# 3                travel  tourism   stb      hk
# 4                travel  tourism   stb      hk
# ...                 ...      ...   ...     ...
# 636304           travel  tourism   stb      hk
# 636305              NaN      NaN   NaN     NaN
# 636306           travel  tourism   stb      hk
# 636307           travel  tourism   stb      hk
# 636308              NaN      NaN   NaN     NaN
#
#                                                Source_URL
# 0       https://www.tripadvisor.com/ShowTopic-g255100-...
# 1       https://www.tripadvisor.com/ShowTopic-g255100-...
# 2       https://www.tripadvisor.com/ShowTopic-g255100-...
# 3       https://www.tripadvisor.com/ShowTopic-g255100-...
# 4       https://www.tripadvisor.com/ShowTopic-g255100-...
# ...                                                   ...
# 636304  https://www.tripadvisor.com/ShowTopic-g255060-...
# 636305                                                NaN
# 636306  https://www.tripadvisor.com/ShowTopic-g255057-...
# 636307  https://www.tripadvisor.com/ShowTopic-g255057-...
# 636308                                                NaN
#
# [636309 rows x 14 columns]

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
#        User                           User_loc                    Date  \
# 11446   NaN              Queensland, Australia            11 years ago
# 11887   NaN                      South Pacific             8 years ago
# 14167   NaN                      South Pacific             5 years ago
# 17264   NaN                Victoria, Australia             5 years ago
# 18911   NaN  Greater Adelaide, South Australia  Jun 10, 2021, 12:41 AM
# ...     ...                                ...                     ...
# 636217  NaN              Queensland, Australia             4 years ago
# 636228  NaN         New South Wales, Australia             4 years ago
# 636240  NaN              Queensland, Australia             5 years ago
# 636259  NaN         New South Wales, Australia             3 years ago
# 636305  NaN                      South Pacific             5 years ago
#
#                                                Discussion  Hashtag  \
# 11446   -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 11887   -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 14167   -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 17264   -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 18911   -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# ...                                                   ...      ...
# 636217  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 636228  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 636240  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 636259  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 636305  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#        Source_title Type User_profile Source Product_category Product Brand  \
# 11446           NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 11887           NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 14167           NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 17264           NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 18911           NaN  NaN          NaN    NaN              NaN     NaN   NaN
# ...             ...  ...          ...    ...              ...     ...   ...
# 636217          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 636228          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 636240          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 636259          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 636305          NaN  NaN          NaN    NaN              NaN     NaN   NaN
#
#        Country Source_URL
# 11446      NaN        NaN
# 11887      NaN        NaN
# 14167      NaN        NaN
# 17264      NaN        NaN
# 18911      NaN        NaN
# ...        ...        ...
# 636217     NaN        NaN
# 636228     NaN        NaN
# 636240     NaN        NaN
# 636259     NaN        NaN
# 636305     NaN        NaN
#
# [5319 rows x 14 columns]

# %%
comments_master.dtypes
# Out:
# User                 object
# User_loc             object
# Date                 object
# Discussion           object
# Hashtag             float64
# Source_title         object
# Type                 object
# User_profile         object
# Source               object
# Product_category     object
# Product              object
# Brand                object
# Country              object
# Source_URL           object
# dtype: object

# %%
#only select comments made in 2021
comments_master = comments_master[comments_master['Date'].str.contains('2021')]

#drop automated comments
comments_master = comments_master[~comments_master['Discussion'].str.contains('Message from Tripadvisor staff')]

comments_master
# Out:
#                    User              User_loc                    Date  \
# 109             jubbing  Melbourne, Australia  Jan 21, 2021, 11:28 PM
# 110     HaveYouEatenYet  Melbourne, Australia  Jan 21, 2021, 11:32 PM
# 111             Famrick            Geelong...  Jan 21, 2021, 11:40 PM
# 112       Loki_crazycat   Ballarat, Australia   Jan 22, 2021, 3:49 AM
# 113             rob3170  Melbourne, Australia   Jan 22, 2021, 7:20 PM
# ...                 ...                   ...                     ...
# 635120       Lorraine D  Melbourne, Australia   Mar 12, 2021, 1:50 AM
# 635121       YorkFoodie     rural West Aussie   Mar 12, 2021, 7:25 PM
# 635122         AmoMondo  Edinburgh, United...   Mar 13, 2021, 4:54 AM
# 635123       Balirunner      Perth, Australia  Mar 14, 2021, 12:16 AM
# 635124       Lorraine D  Melbourne, Australia   Mar 14, 2021, 4:51 AM
#
#                                                Discussion  Hashtag  \
# 109     Hi there, we'll be driving from Ocean Grove to...      NaN
# 110     Port Campbell would be my choice if I want to ...      NaN
# 111     Agree with #1 take the inland route to Port Ca...      NaN
# 112     Your other option is Princetown, but accommoda...      NaN
# 113     Apollo Bay is generally my choice for a 1 nigh...      NaN
# ...                                                   ...      ...
# 635120  I am a 50 yo female heading to WA for five or ...      NaN
# 635121  I would see where the pick up points for the t...      NaN
# 635122  I agree with YF.\nI’ve done day tours and over...      NaN
# 635123  My choice that time of the year is stay close ...      NaN
# 635124                  thanks for your input everyone :)      NaN
#
#                                              Source_title   Type  \
# 109                            Where to stay for 1 night?  forum
# 110                            Where to stay for 1 night?  forum
# 111                            Where to stay for 1 night?  forum
# 112                            Where to stay for 1 night?  forum
# 113                            Where to stay for 1 night?  forum
# ...                                                   ...    ...
# 635120  Best Location for Accommodation - Five Night T...  forum
# 635121  Best Location for Accommodation - Five Night T...  forum
# 635122  Best Location for Accommodation - Five Night T...  forum
# 635123  Best Location for Accommodation - Five Night T...  forum
# 635124  Best Location for Accommodation - Five Night T...  forum
#
#                                              User_profile       Source  \
# 109     https://www.tripadvisor.com/Profile/jubbing?ta...  tripadvisor
# 110     https://www.tripadvisor.com/Profile/HaveYouEat...  tripadvisor
# 111     https://www.tripadvisor.com/Profile/Famrick?ta...  tripadvisor
# 112     https://www.tripadvisor.com/Profile/Loki_crazy...  tripadvisor
# 113     https://www.tripadvisor.com/Profile/rob3170?ta...  tripadvisor
# ...                                                   ...          ...
# 635120  https://www.tripadvisor.com/Profile/729lorrain...  tripadvisor
# 635121  https://www.tripadvisor.com/Profile/YorkFoodie...  tripadvisor
# 635122  https://www.tripadvisor.com/Profile/AmoMondo?t...  tripadvisor
# 635123  https://www.tripadvisor.com/Profile/Balirunner...  tripadvisor
# 635124  https://www.tripadvisor.com/Profile/729lorrain...  tripadvisor
#
#        Product_category  Product Brand Country  \
# 109              travel  tourism   stb      hk
# 110              travel  tourism   stb      hk
# 111              travel  tourism   stb      hk
# 112              travel  tourism   stb      hk
# 113              travel  tourism   stb      hk
# ...                 ...      ...   ...     ...
# 635120           travel  tourism   stb      hk
# 635121           travel  tourism   stb      hk
# 635122           travel  tourism   stb      hk
# 635123           travel  tourism   stb      hk
# 635124           travel  tourism   stb      hk
#
#                                                Source_URL
# 109     https://www.tripadvisor.com/ShowTopic-g2269364...
# 110     https://www.tripadvisor.com/ShowTopic-g2269364...
# 111     https://www.tripadvisor.com/ShowTopic-g2269364...
# 112     https://www.tripadvisor.com/ShowTopic-g2269364...
# 113     https://www.tripadvisor.com/ShowTopic-g2269364...
# ...                                                   ...
# 635120  https://www.tripadvisor.com/ShowTopic-g255103-...
# 635121  https://www.tripadvisor.com/ShowTopic-g255103-...
# 635122  https://www.tripadvisor.com/ShowTopic-g255103-...
# 635123  https://www.tripadvisor.com/ShowTopic-g255103-...
# 635124  https://www.tripadvisor.com/ShowTopic-g255103-...
#
# [12428 rows x 14 columns]

# %%
#country is mislabelled so have to change country

comments_master['Country'] = comments_master['Country'].replace('hk','au')

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/STB_GTT_Step1Output/Australia.csv",index=False)
