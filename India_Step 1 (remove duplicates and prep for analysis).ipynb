# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

os.chdir("/Users/chrtjen/Desktop/STB_GTT/India")

# %%
filenames = os.listdir()

dfs = []
df_names = []
for filename in filenames:
    if 'csv' in filename:
        df_names.append(filename)
        dfs.append(pd.read_csv(filename))
  
print(f'read the following dataframes: {df_names}')
# Out:
# read the following dataframes: ['Simlakufrifagunaldherabyhptdcbusquery.csv', 'FourAdultsyourassistancepleaseCHANDIGARHFEB2019.csv', 'RoadtripfromDelhitoPuneJuly2021end.csv', 'ItineraryadviceRajasthan3nights.csv', 'TravelingtoIndiawithaMavicProDrone.csv', 'Howtoreachmunnarfromootybybus.csv', '4dayskeralaenoughtime.csv', 'RishikeshsharetaxiservicetoRudraprayag.csv', 'planingtonovemberinNainital.csv', 'TravelfromGuwahatitoShillong.csv', 'Gulmargtrip.csv', 'Daytriptomatheran.csv', 'Nighthaltbetweenmunnartokovalam.csv', 'RecallofTemporaryApplicationID.csv', 'Goanatms.csv', 'RivaGoldCoast.csv', 'FloodconditioninKannurTravelingon14thAug2019.csv', 'Bussserviceavailablity.csv', 'Changemyphonenumber.csv', 'WhichonlineSafariprovideristrustedreliable.csv', 'GoaNorthorSouthorboth.csv', 'Goatripwithfamily.csv', 'Planningtovisitdehradun.csv', 'PaidDarshanTicket.csv', 'WhisperingPalmsCandolimGoa.csv', 'SolotravellerlandinginlehonSept29.csv', 'Callfortestingofallmigrantsandforeignvisitorsretu.csv', 'RanikhetChaukoriMunsiaryNanitaltrip.csv', 'CabtravelfromujjaintoOmkareshwartempleisland.csv', 'Kerelatrip.csv', 'Tourcar.csv', 'Fireplaceavailableinrooms.csv', 'NeedHotelRecommendationArrivingLateFromTrainwKids.csv', 'SelfDriveCar.csv', 'MumbaitoTranscityDeveloperBangaloreBikeTrip.csv', 'udaipurkhumbhalgarhranakpurhaldighatitripinoct19.csv', 'wheretheyaresoldbutaneGascartridges.csv', 'VFSGlobalFiveyearvisaapplicationataleofwoe.csv', 'isEpassstillrequiredtotravelfromkanyakumaritotvm.csv', 'Refundmany.csv', 'IsTravelopentoManali.csv', 'StrangerandSons.csv', 'Vagamonsafe.csv', 'MeghalayaAgecave.csv', 'Priceforadriver.csv', 'Surfbreaks.csv', 'WaitlistonIndiatrain.csv', 'TransitvisaforMoscowandflightconnections.csv', 'ThingstobuyinKhajuraho.csv', 'WhatisthedistanceJammubusstopforSrinagarbus.csv', 'Rajasthanitnerary.csv', 'Floodwarningsinallepey.csv', 'ChennaiAirporttoVailankanniChurch.csv', 'PunetoKeralaroadtripinAugust.csv', 'srinagarpahalgamgulmargsuggestBESITINERARYPLS.csv', 'FernandesWoodenCottagesPalolem.csv', 'daywisemunnaritinerayplzfor2days.csv', '10thDecemberflightsthomascook.csv', 'ayurvedicdoctor.csv', 'Olddelhineighborhood.csv', 'HALMuseumOpen.csv', 'ConnectinginDelhi.csv', 'reliabletaxiserviceinThirukadaiyur.csv', 'ArdhkuwariDarshanPossibleWhenwereturnfromBhawan.csv', 'Bangaramtothinakkaraboatcharges.csv', 'IRCTCGatewaybanks.csv', 'HowtoreachKodaikanal.csv', 'QueryregardingSterlingPuri.csv', 'Bikerentalindehradun.csv', 'manalitodelhichandigarh.csv', 'TripPlanAdvise.csv', 'TrainAirfromJaisalmertoDelhi.csv', 'RatefortaxifromVascoMadgaontocandolim.csv', 'Newyear.csv', 'IsitraininginSikkim.csv', 'TaxiDriverandplacestovisit.csv', 'WagahBorderbeatingretreatceremonyduringrainyseason.csv', 'Pnrstatus.csv', 'Kumauntourwithelderlypeople.csv', 'NewDelhiCitytraveltimes.csv', 'LOSARmeansLadakhiNewyear.csv', 'GoldenTriangleGoaTripAdvice.csv', 'NospectatorsallowedforWagahborder.csv', 'NewDelhiInternationalAirportTerminal3.csv', 'TouroperatorsatSikkim.csv', 'AuliinDecember.csv', 'Wheretostayinshnongdengdawki.csv', 'Lavaloleygaonroshopinpuja.csv', 'ShimlaManalitripIssue.csv', 'Augustagoodtimetotraveltoudaipur.csv', 'Localbazaars.csv', 'medicalinsuranceforanaustralianinindia.csv', 'ItenraryforUdaipurmountabutrip.csv', 'FromHampitoGoabycabViaBadamiPattadakal.csv', 'VisittoWalongandKibithu.csv', 'Caranddriver.csv', 'PangongvsKaigarTso.csv', 'TransportationinSonamarg.csv', 'Ootytripon15thfeb.csv', 'WanttoMakemycoupletripinKashmir.csv', 'VapingandecigarettesinIndia.csv', 'fromnewdelhitolahorebyair.csv', 'VisittoSrinagarGulmargandSonmarginJulyend.csv', 'PlanningtovisitinDecemberend.csv', 'ManaliinFebuary.csv', 'Visaforacruisestop.csv', 'TrekkinginDecember.csv', 'Takingtaxiiscostierthanflightingoa.csv', 'MydesiretripakaORIAMOPrivateLimited.csv', 'DomesticarrivaltothedomesticdepartureatT3Delhiairpo.csv', 'NeedtosuggestionforSaurashtratrip.csv', 'Situationofrain.csv', 'GoaDreaming.csv', 'IwanttogofortripsingroupsbutImalone.csv', 'Covidstatus.csv', 'HotelinNorthGoawi ...

# %%
#create the master dataframe

comments_master = pd.concat(dfs, ignore_index=True, sort=False).dropna(subset=['Discussion']).reset_index(drop=True)
comments_master
# Out:
#                  User               User_loc                    Date  \
# 0        kush_ank1988                    NaN              1 year ago
# 1           Rahul2604         Muzaffarpur...              1 year ago
# 2       World Trotter  Dubai, United Arab...             2 years ago
# 3              Wotsit         United Kingdom             2 years ago
# 4       World Trotter  Dubai, United Arab...             2 years ago
# ...               ...                    ...                     ...
# 296605         MRahul   Singapore, Singapore  Mar 30, 2021, 11:27 PM
# 296606    Nagaraj B V       Bengaluru, India  Mar 31, 2021, 11:55 PM
# 296607    Nagaraj B V       Bengaluru, India  Mar 31, 2021, 11:56 PM
# 296608         vistet                   Umeå    Apr 1, 2021, 3:54 AM
# 296609         MRahul   Singapore, Singapore    Apr 1, 2021, 4:10 AM
#
#                                                Discussion  Hashtag  \
# 0       If I book hptdc bus from simla for local sight...      NaN
# 1       Skiing? When you are going? If going during no...      NaN
# 2       17th Feb 19 (Sun): Chandigarh Sightseeing\nRoc...      NaN
# 3                                         Duplicated post      NaN
# 4       Please see the dates. Title is same\nOur trip ...      NaN
# ...                                                   ...      ...
# 296605  Tangtse is lower than Pangong Tso, it just sli...      NaN
# 296606                                 Thanks Rajanish Ji      NaN
# 296607  So true. Appreciate your clarity on this matte...      NaN
# 296608  Re # 3 : Tangtse is within safety guidelines: ...      NaN
# 296609  On the plus side, staying at Tangtse will redu...      NaN
#
#                                              Source_title   Type  \
# 0            Simla-kufri-fagu-naldhera by hptdc bus query  forum
# 1            Simla-kufri-fagu-naldhera by hptdc bus query  forum
# 2       Four Adults your assistance please! CHANDIGARH...  forum
# 3       Four Adults your assistance please! CHANDIGARH...  forum
# 4       Four Adults your assistance please! CHANDIGARH...  forum
# ...                                                   ...    ...
# 296605                                  Pangong Tso visit  forum
# 296606                                  Pangong Tso visit  forum
# 296607                                  Pangong Tso visit  forum
# 296608                                  Pangong Tso visit  forum
# 296609                                  Pangong Tso visit  forum
#
#                                              User_profile       Source  \
# 0       https://www.tripadvisor.com/Profile/kush_ank19...  tripadvisor
# 1       https://www.tripadvisor.com/Profile/Rahul2604?...  tripadvisor
# 2       https://www.tripadvisor.com/Profile/OnAir56824...  tripadvisor
# 3       https://www.tripadvisor.com/Profile/Wotsittt?t...  tripadvisor
# 4       https://www.tripadvisor.com/Profile/OnAir56824...  tripadvisor
# ...                                                   ...          ...
# 296605  https://www.tripadvisor.com/Profile/MRahul?tab...  tripadvisor
# 296606  https://www.tripadvisor.com/Profile/Nagaraj415...  tripadvisor
# 296607  https://www.tripadvisor.com/Profile/Nagaraj415...  tripadvisor
# 296608  https://www.tripadvisor.com/Profile/vistet?tab...  tripadvisor
# 296609  https://www.tripadvisor.com/Profile/MRahul?tab...  tripadvisor
#
#        Product_category  Product Brand Country  \
# 0                travel  tourism   stb      id
# 1                travel  tourism   stb      id
# 2                travel  tourism   stb      id
# 3                travel  tourism   stb      id
# 4                travel  tourism   stb      id
# ...                 ...      ...   ...     ...
# 296605           travel  tourism   stb      id
# 296606           travel  tourism   stb      id
# 296607           travel  tourism   stb      id
# 296608           travel  tourism   stb      id
# 296609           travel  tourism   stb      id
#
#                                                Source_URL
# 0       https://www.tripadvisor.com/ShowTopic-g777776-...
# 1       https://www.tripadvisor.com/ShowTopic-g777776-...
# 2       https://www.tripadvisor.com/ShowTopic-g297596-...
# 3       https://www.tripadvisor.com/ShowTopic-g297596-...
# 4       https://www.tripadvisor.com/ShowTopic-g297596-...
# ...                                                   ...
# 296605  https://www.tripadvisor.com/ShowTopic-g297624-...
# 296606  https://www.tripadvisor.com/ShowTopic-g297624-...
# 296607  https://www.tripadvisor.com/ShowTopic-g297624-...
# 296608  https://www.tripadvisor.com/ShowTopic-g297624-...
# 296609  https://www.tripadvisor.com/ShowTopic-g297624-...
#
# [296610 rows x 14 columns]

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
#        User                    User_loc                    Date  \
# 359     NaN                 India, Asia              1 year ago
# 2127    NaN                 India, Asia   Dec 4, 2020, 12:41 AM
# 2628    NaN      Auli, Chamoli District              1 year ago
# 4017    NaN  Bardez, North Goa District              1 year ago
# 4391    NaN                 India, Asia              1 year ago
# ...     ...                         ...                     ...
# 296496  NaN               Punjab, India              1 year ago
# 296519  NaN                        Asia              1 year ago
# 296524  NaN          Maharashtra, India              1 year ago
# 296536  NaN                 India, Asia  Jan 27, 2021, 12:40 AM
# 296577  NaN                 India, Asia  Oct 24, 2020, 12:41 AM
#
#                                                Discussion  Hashtag  \
# 359     -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 2127    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 2628    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 4017    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 4391    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# ...                                                   ...      ...
# 296496  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 296519  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 296524  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 296536  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 296577  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#        Source_title Type User_profile Source Product_category Product Brand  \
# 359             NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 2127            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 2628            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 4017            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 4391            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# ...             ...  ...          ...    ...              ...     ...   ...
# 296496          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 296519          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 296524          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 296536          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 296577          NaN  NaN          NaN    NaN              NaN     NaN   NaN
#
#        Country Source_URL
# 359        NaN        NaN
# 2127       NaN        NaN
# 2628       NaN        NaN
# 4017       NaN        NaN
# 4391       NaN        NaN
# ...        ...        ...
# 296496     NaN        NaN
# 296519     NaN        NaN
# 296524     NaN        NaN
# 296536     NaN        NaN
# 296577     NaN        NaN
#
# [9190 rows x 14 columns]

# %%
comments_master.dtypes
# Out:
# User                 object
# User_loc             object
# Date                 object
# Discussion           object
# Hashtag             float64
# Source_title         object
# Type                 object
# User_profile         object
# Source               object
# Product_category     object
# Product              object
# Brand                object
# Country              object
# Source_URL           object
# dtype: object

# %%
#only select comments made in 2021
comments_master = comments_master[comments_master['Date'].str.contains('2021')]

#drop automated comments
comments_master = comments_master[~comments_master['Discussion'].str.contains('Message from Tripadvisor staff')]

comments_master
# Out:
#                   User              User_loc                    Date  \
# 12            pulkit93   National Capital...    Jun 6, 2021, 4:37 AM
# 14            pulkit93   National Capital...   Jun 23, 2021, 2:24 AM
# 15      gts tours agra           Agra, India   Jul 1, 2021, 11:22 PM
# 16              Bornav          Assam, India    Jul 3, 2021, 3:05 AM
# 17                 NaN           India, Asia    Jul 4, 2021, 1:45 AM
# ...                ...                   ...                     ...
# 296605          MRahul  Singapore, Singapore  Mar 30, 2021, 11:27 PM
# 296606     Nagaraj B V      Bengaluru, India  Mar 31, 2021, 11:55 PM
# 296607     Nagaraj B V      Bengaluru, India  Mar 31, 2021, 11:56 PM
# 296608          vistet                  Umeå    Apr 1, 2021, 3:54 AM
# 296609          MRahul  Singapore, Singapore    Apr 1, 2021, 4:10 AM
#
#                                                Discussion  Hashtag  \
# 12      I am planning to drive from Delhi to Pune in l...      NaN
# 14      #1\nSelf promotion / advertising is not allowe...      NaN
# 15      Hi Bornav,\nWhich statement in my post is actu...      NaN
# 16      Hii pulkit ji very easy nowdays all the roads ...      NaN
# 17      Not yours Pulkit, I was referring to the one w...      NaN
# ...                                                   ...      ...
# 296605  Tangtse is lower than Pangong Tso, it just sli...      NaN
# 296606                                 Thanks Rajanish Ji      NaN
# 296607  So true. Appreciate your clarity on this matte...      NaN
# 296608  Re # 3 : Tangtse is within safety guidelines: ...      NaN
# 296609  On the plus side, staying at Tangtse will redu...      NaN
#
#                                         Source_title   Type  \
# 12      Road trip from Delhi to Pune (July 2021 end)  forum
# 14      Road trip from Delhi to Pune (July 2021 end)  forum
# 15      Road trip from Delhi to Pune (July 2021 end)  forum
# 16      Road trip from Delhi to Pune (July 2021 end)  forum
# 17                                               NaN    NaN
# ...                                              ...    ...
# 296605                             Pangong Tso visit  forum
# 296606                             Pangong Tso visit  forum
# 296607                             Pangong Tso visit  forum
# 296608                             Pangong Tso visit  forum
# 296609                             Pangong Tso visit  forum
#
#                                              User_profile       Source  \
# 12      https://www.tripadvisor.com/Profile/pulkit93?t...  tripadvisor
# 14      https://www.tripadvisor.com/Profile/pulkit93?t...  tripadvisor
# 15      https://www.tripadvisor.com/Profile/gtstoursag...  tripadvisor
# 16      https://www.tripadvisor.com/Profile/Bornav?tab...  tripadvisor
# 17                                                    NaN          NaN
# ...                                                   ...          ...
# 296605  https://www.tripadvisor.com/Profile/MRahul?tab...  tripadvisor
# 296606  https://www.tripadvisor.com/Profile/Nagaraj415...  tripadvisor
# 296607  https://www.tripadvisor.com/Profile/Nagaraj415...  tripadvisor
# 296608  https://www.tripadvisor.com/Profile/vistet?tab...  tripadvisor
# 296609  https://www.tripadvisor.com/Profile/MRahul?tab...  tripadvisor
#
#        Product_category  Product Brand Country  \
# 12               travel  tourism   stb      id
# 14               travel  tourism   stb      id
# 15               travel  tourism   stb      id
# 16               travel  tourism   stb      id
# 17                  NaN      NaN   NaN     NaN
# ...                 ...      ...   ...     ...
# 296605           travel  tourism   stb      id
# 296606           travel  tourism   stb      id
# 296607           travel  tourism   stb      id
# 296608           travel  tourism   stb      id
# 296609           travel  tourism   stb      id
#
#                                                Source_URL
# 12      https://www.tripadvisor.com/ShowTopic-g297654-...
# 14      https://www.tripadvisor.com/ShowTopic-g297654-...
# 15      https://www.tripadvisor.com/ShowTopic-g297654-...
# 16      https://www.tripadvisor.com/ShowTopic-g297654-...
# 17                                                    NaN
# ...                                                   ...
# 296605  https://www.tripadvisor.com/ShowTopic-g297624-...
# 296606  https://www.tripadvisor.com/ShowTopic-g297624-...
# 296607  https://www.tripadvisor.com/ShowTopic-g297624-...
# 296608  https://www.tripadvisor.com/ShowTopic-g297624-...
# 296609  https://www.tripadvisor.com/ShowTopic-g297624-...
#
# [9431 rows x 14 columns]

# %%
#country is mislabelled so have to change country

comments_master['Country'] = comments_master['Country'].replace('id','in')

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/Step1Output/India.csv",index=False)
