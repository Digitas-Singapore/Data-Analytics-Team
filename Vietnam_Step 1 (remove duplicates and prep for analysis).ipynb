# %%
import os
import pandas as pd
import numpy as np
import string

from pprint import pprint

os.chdir("/Users/chrtjen/Desktop/STB_GTT/Vietnam")

# %%
filenames = os.listdir()

dfs = []
df_names = []
for filename in filenames:
    if 'csv' in filename:
        df_names.append(filename)
        dfs.append(pd.read_csv(filename))
  
print(f'read the following dataframes: {df_names}')
# Out:
# read the following dataframes: ['HoiAnTailorrecommendationuptodate.csv', 'Pleasehelpsuggestboatforwintertripwithatripleroom.csv', 'TransportationHanoitoDongHoi.csv', 'TunnelvisitafterMekongDelta.csv', 'ViettelTouristSiminCambodia.csv', 'SuitesMajesticHotelvsGrandHotel.csv', '10ReasonstoVisitVietnamin2009.csv', 'HowdoIdealwithspendingmoney.csv', 'LaoCaitoHekou.csv', 'Nomotorbikes.csv', 'Lockedsuitcases.csv', 'GlutenFreeRestaurantforNYE.csv', 'ImpressionsBoutiqueHoiAn.csv', 'TyphooninNhaTrang.csv', 'HoangAnhQuyNhonhotelcontactinfo.csv', 'FlyinwithBoxedWine.csv', 'TrainBusTimetable.csv', 'BookingahotelinHanoiifgoingtoHalongBaycruise.csv', 'HalongBayVietnamCruisetour.csv', 'HCMCSVietnamandCambodiainthefirsthalfofNovember.csv', 'VietnamAir1hr55minlayoverinSGNEnough.csv', 'costfortaxifromairport.csv', 'samedaytripDanangairporttobanahill.csv', 'JBRHalongBayandColumbusCruises.csv', 'PhoinHanoireviewintheAustralian.csv', 'BustravelfromBenTretoSaigon.csv', 'Taxiquestion.csv', 'FuramaDanangVietnam.csv', 'TrainfromHCMCtoMuiNe.csv', 'SleeperbustoSapa.csv', 'AnupdatedviewonHoiAntailorsMrXeandNhiNhi.csv', 'Driveback.csv', 'IdeasformylastdayinHCMC.csv', 'VictoryStarCruise.csv', 'Hopefullythisitinerarywillwork.csv', 'Hanoistationfacilities.csv', 'VinHungRiversidevsEmerald.csv', 'Artificialplants.csv', 'HoChiMinhtransfertoPOhnomPenh.csv', 'VisaprocedureforIndianstovisitVietnamCambodia.csv', 'NationalDaySeptember2inHanoi.csv', 'VietnamHoneymoonTravelAgentorNo.csv', 'hanoiweathernow.csv', 'justaftersomethoughtsonpricetourcheers.csv', 'Officialwebsiteforvietnamtoristoffice.csv', 'IsitpossibletodoSapawithoutapackagetour.csv', 'HanoiAttractionsDressCode.csv', 'BestHotelinhanoifor2adultsand2childrenplease.csv', 'CanThoaccommodation.csv', 'GoingtoMySon.csv', 'Lookingforplacetostay.csv', 'AswiththeothereIndochinaSailsorIndochinaJunk.csv', 'HanoiArtisanBoutiqueHotelorArtBoutiqueHotelHanoi.csv', 'NewhotelnearNovotel.csv', 'Helponmy3MonthTrip.csv', 'LookingforhotelguesthouseinHanoiwithairportpickup.csv', 'UsingATMs.csv', 'onlinebookingforfastboattovungtau.csv', 'Locationandhotelsuggestionsthanks.csv', 'RestaurantsrecommendationbyLeMeridien.csv', 'DaytourfromHCMC.csv', 'TropicalStormGaemicomingfortheweekend.csv', 'Onedaylongtrekhikerun.csv', 'Simpleitinerarywantedfor12daysinOctober.csv', 'CitadelopenlateonThursdays.csv', 'Whentobookairlinetickets.csv', 'needhelp306090dayvisaforvietnamfromcambodia.csv', 'BusfromSapatoLaos.csv', 'AguideinHaNoiwithacar.csv', 'SuggestionsforfirstVietnamtrip.csv', 'NightlifeinSaigon.csv', 'cruiseMekongRiver.csv', '10daytrip.csv', 'Firstvisithelpneedcheaphotelwithpool.csv', 'TravelHoiAntoSaigon.csv', 'BookingflightsVietnamAirbutpassportnumberwillchange.csv', 'MuiNetoHCMCAirport1Augustmornin7seatertoshare.csv', 'ShorttripinHoChiMinh.csv', 'AveragePricesinVietnam.csv', 'Elephantsinvietnam.csv', 'SouthWestVietnamHaTienorRachGiatoHCMC.csv', 'Splittingthetimebetweentownandbeach.csv', 'HalongBayininJuly.csv', 'PrivatetaxitoursinHoChiMinhCityandalsoNhaTrang.csv', 'HoiAnasbase.csv', 'TransportationfromDaNangairporttoHue.csv', 'VietJetAirHCMtoIncheonKorea.csv', 'rayban.csv', 'Changingbackdongondeparturewarning.csv', 'HaiPhongtoCatBapleasehelp.csv', 'Niggtlife.csv', '15dayVISAonarrivaladvice.csv', 'WhenisitwarmenoughtoswiminHalongBay.csv', 'HonKhoisaltfields.csv', '5daysinHanoiHalongSapa.csv', 'Flightstopoveradvice.csv', 'HowtogettoHoiAnfromeitherHCMCorHanoi.csv', 'IsMinMaxTravelGood.csv', 'KayakingandSnorkeling.csv', 'GoingtoVietnamWithaPeanutTreeNutAllergy.csv', 'VisitTamCocinDec.csv', 'IsNhaTrangforus.csv', 'bustickettoNanning.csv', 'IsfacebookbannedinHCMC.csv', 'Adviceneededpleasehelp.csv', 'HowtogetGrabwithoutroamingonAustralianphone.csv', 'JoesBar.csv', '6D5Nitineraryandleftluggagefacilitiesattrainstation.csv', 'BeachChoice.csv', '2daysonPhuQuocIslandwhattodo.csv', 'BestwaytogetfromHCMCtoHaTien.csv', 'TakingDongoutofVietnam.csv', 'tourcompanyrequirements.csv', 'Arewesayingnotoahandbag.csv', 'privatecharters.csv', 'Ontheway.csv', 'Ja ...

# %%
#create the master dataframe

comments_master = pd.concat(dfs, ignore_index=True, sort=False).dropna(subset=['Discussion']).reset_index(drop=True)
comments_master
# Out:
#                User               User_loc          Date  \
# 0        jamiemacNz   Sway, United Kingdom  11 years ago
# 1            hans k     rotterdam, Holland  11 years ago
# 2        jamiemacNz   Sway, United Kingdom  11 years ago
# 3         tommy910i                 Sydney  11 years ago
# 4               NaN          Vietnam, Asia  11 years ago
# ...             ...                    ...           ...
# 685081  BoulderBill      Boulder, Colorado   6 years ago
# 685082     onmymark   Melbourne, Australia   6 years ago
# 685083        mel f   Gravesend, United...   6 years ago
# 685084     onmymark   Melbourne, Australia   6 years ago
# 685085          NaN  Mekong Delta, Vietnam   5 years ago
#
#                                                Discussion  Hashtag  \
# 0       hello im going to Hoi An in july and im going ...      NaN
# 1       I know the place you are looking for. Tu'ong L...      NaN
# 2                              thanks very much for that.      NaN
# 3       Hey there\nYou can visit Elegant tailor at 66 ...      NaN
# 4       -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# ...                                                   ...      ...
# 685081  Follow the old adage - pack very lightly, then...      NaN
# 685082  Passport, iphone, simple firstaid kit incl imm...      NaN
# 685083  Thank you for the advice!!! Need to now half w...      NaN
# 685084  Waterproofs only needed if actually trecking.\...      NaN
# 685085  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#                                           Source_title   Type  \
# 0               Hoi An Tailor recommendation upto date  forum
# 1               Hoi An Tailor recommendation upto date  forum
# 2               Hoi An Tailor recommendation upto date  forum
# 3               Hoi An Tailor recommendation upto date  forum
# 4                                                  NaN    NaN
# ...                                                ...    ...
# 685081  What to pack for 2 months in Siuth East Asia?!  forum
# 685082  What to pack for 2 months in Siuth East Asia?!  forum
# 685083  What to pack for 2 months in Siuth East Asia?!  forum
# 685084  What to pack for 2 months in Siuth East Asia?!  forum
# 685085                                             NaN    NaN
#
#                                              User_profile       Source  \
# 0       https://www.tripadvisor.com/Profile/jamiemacNz...  tripadvisor
# 1       https://www.tripadvisor.com/MemberProfile-ccf-...  tripadvisor
# 2       https://www.tripadvisor.com/Profile/jamiemacNz...  tripadvisor
# 3       https://www.tripadvisor.com/Profile/tommy910i?...  tripadvisor
# 4                                                     NaN          NaN
# ...                                                   ...          ...
# 685081  https://www.tripadvisor.com/Profile/BoulderBil...  tripadvisor
# 685082  https://www.tripadvisor.com/Profile/onmymark?t...  tripadvisor
# 685083  https://www.tripadvisor.com/Profile/810melf?ta...  tripadvisor
# 685084  https://www.tripadvisor.com/Profile/onmymark?t...  tripadvisor
# 685085                                                NaN          NaN
#
#        Product_category  Product Brand Country  \
# 0                travel  tourism   stb   sg_jp
# 1                travel  tourism   stb   sg_jp
# 2                travel  tourism   stb   sg_jp
# 3                travel  tourism   stb   sg_jp
# 4                   NaN      NaN   NaN     NaN
# ...                 ...      ...   ...     ...
# 685081           travel  tourism   stb   sg_jp
# 685082           travel  tourism   stb   sg_jp
# 685083           travel  tourism   stb   sg_jp
# 685084           travel  tourism   stb   sg_jp
# 685085              NaN      NaN   NaN     NaN
#
#                                                Source_URL
# 0       https://www.tripadvisor.com/ShowTopic-g298082-...
# 1       https://www.tripadvisor.com/ShowTopic-g298082-...
# 2       https://www.tripadvisor.com/ShowTopic-g298082-...
# 3       https://www.tripadvisor.com/ShowTopic-g298082-...
# 4                                                     NaN
# ...                                                   ...
# 685081  https://www.tripadvisor.com/ShowTopic-g293921-...
# 685082  https://www.tripadvisor.com/ShowTopic-g293921-...
# 685083  https://www.tripadvisor.com/ShowTopic-g293921-...
# 685084  https://www.tripadvisor.com/ShowTopic-g293921-...
# 685085                                                NaN
#
# [685086 rows x 14 columns]

# %%
#get duplicated comments

duplicates = comments_master[comments_master.duplicated()]
duplicates_index = list(duplicates.index.values)
duplicates
# Out:
#        User                     User_loc          Date  \
# 1399    NaN                         Asia   8 years ago
# 5025    NaN                Vietnam, Asia   3 years ago
# 5610    NaN                Vietnam, Asia   4 years ago
# 6350    NaN                Vietnam, Asia   2 years ago
# 8347    NaN                Vietnam, Asia   7 years ago
# ...     ...                          ...           ...
# 685000  NaN                Vietnam, Asia   5 years ago
# 685016  NaN  Quang Nam Province, Vietnam  11 years ago
# 685025  NaN                         Asia   3 years ago
# 685048  NaN                         Asia   4 years ago
# 685075  NaN                Vietnam, Asia  10 years ago
#
#                                                Discussion  Hashtag  \
# 1399    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 5025    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 5610    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 6350    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 8347    -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# ...                                                   ...      ...
# 685000  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 685016  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 685025  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 685048  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
# 685075  -:- Message from Tripadvisor staff -:-\nThis t...      NaN
#
#        Source_title Type User_profile Source Product_category Product Brand  \
# 1399            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 5025            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 5610            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 6350            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 8347            NaN  NaN          NaN    NaN              NaN     NaN   NaN
# ...             ...  ...          ...    ...              ...     ...   ...
# 685000          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 685016          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 685025          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 685048          NaN  NaN          NaN    NaN              NaN     NaN   NaN
# 685075          NaN  NaN          NaN    NaN              NaN     NaN   NaN
#
#        Country Source_URL
# 1399       NaN        NaN
# 5025       NaN        NaN
# 5610       NaN        NaN
# 6350       NaN        NaN
# 8347       NaN        NaN
# ...        ...        ...
# 685000     NaN        NaN
# 685016     NaN        NaN
# 685025     NaN        NaN
# 685048     NaN        NaN
# 685075     NaN        NaN
#
# [18758 rows x 14 columns]

# %%
comments_master.dtypes
# Out:
# User                 object
# User_loc             object
# Date                 object
# Discussion           object
# Hashtag             float64
# Source_title         object
# Type                 object
# User_profile         object
# Source               object
# Product_category     object
# Product              object
# Brand                object
# Country              object
# Source_URL           object
# dtype: object

# %%
#only select comments made in 2021
comments_master = comments_master[comments_master['Date'].str.contains('2021')]

#drop automated comments
comments_master = comments_master[~comments_master['Discussion'].str.contains('Message from Tripadvisor staff')]

comments_master
# Out:
#                   User               User_loc                    Date  \
# 3246             DPXR2      Sydney, Australia  May 24, 2021, 10:53 AM
# 3247       bertieboy01  Birkenhead, United...  May 27, 2021, 11:01 AM
# 3248             DPXR2      Sydney, Australia   May 28, 2021, 7:55 AM
# 6790        Greg122112  New York City, New...   Jan 8, 2021, 10:21 AM
# 6791         scottj765   Melbourne, Australia    Jan 8, 2021, 4:57 PM
# ...                ...                    ...                     ...
# 682450     manatdollar      Dollar, United...   Jan 21, 2021, 3:20 PM
# 682451          ross m       Perth, Australia   Jan 21, 2021, 8:30 PM
# 682452  OasisBarHaTien       Ha Tien, Vietnam  Jan 21, 2021, 10:51 PM
# 682453         Techboy        Vancouver, B.C.  Jan 22, 2021, 12:24 AM
# 682454        69bertie     Lincoln, United...   Jan 24, 2021, 1:54 PM
#
#                                                Discussion  Hashtag  \
# 3246    I'm due to receive a parcel from UK. It was po...      NaN
# 3247    Hi We had a delay with a parcel that said simi...      NaN
# 3248    My parcel cleared customs on 26 May. Yep!, aro...      NaN
# 6790    Hi, everyone,\nI know, it's questionable to pl...      NaN
# 6791    Don't know if you can fly direct to Danang, bu...      NaN
# ...                                                   ...      ...
# 682450  Well, there are two parts to your question:\nL...      NaN
# 682451  There is also the question of quarantine if th...      NaN
# 682452  As manatdollar says.there are 2 entirely separ...      NaN
# 682453  It's visa free to visit Asean countries in whi...      NaN
# 682454  Compass775098 A Vietnamese getting a passport ...      NaN
#
#                                              Source_title   Type  \
# 3246    parcel from UK - Delays going through Vietnam ...  forum
# 3247    parcel from UK - Delays going through Vietnam ...  forum
# 3248    parcel from UK - Delays going through Vietnam ...  forum
# 6790                                    resort in vietnam  forum
# 6791                                    resort in vietnam  forum
# ...                                                   ...    ...
# 682450  What documents do Vietnamese need in order to ...  forum
# 682451  What documents do Vietnamese need in order to ...  forum
# 682452  What documents do Vietnamese need in order to ...  forum
# 682453  What documents do Vietnamese need in order to ...  forum
# 682454  What documents do Vietnamese need in order to ...  forum
#
#                                              User_profile       Source  \
# 3246    https://www.tripadvisor.com/Profile/DPXR2?tab=...  tripadvisor
# 3247    https://www.tripadvisor.com/Profile/bertieboy0...  tripadvisor
# 3248    https://www.tripadvisor.com/Profile/DPXR2?tab=...  tripadvisor
# 6790    https://www.tripadvisor.com/Profile/Greg122112...  tripadvisor
# 6791    https://www.tripadvisor.com/Profile/scottj765?...  tripadvisor
# ...                                                   ...          ...
# 682450  https://www.tripadvisor.com/Profile/manatdolla...  tripadvisor
# 682451  https://www.tripadvisor.com/Profile/rossm178?t...  tripadvisor
# 682452  https://www.tripadvisor.com/Profile/OasisBarHa...  tripadvisor
# 682453  https://www.tripadvisor.com/Profile/Techboy?ta...  tripadvisor
# 682454  https://www.tripadvisor.com/Profile/69bertie?t...  tripadvisor
#
#        Product_category  Product Brand Country  \
# 3246             travel  tourism   stb   sg_jp
# 3247             travel  tourism   stb   sg_jp
# 3248             travel  tourism   stb   sg_jp
# 6790             travel  tourism   stb   sg_jp
# 6791             travel  tourism   stb   sg_jp
# ...                 ...      ...   ...     ...
# 682450           travel  tourism   stb   sg_jp
# 682451           travel  tourism   stb   sg_jp
# 682452           travel  tourism   stb   sg_jp
# 682453           travel  tourism   stb   sg_jp
# 682454           travel  tourism   stb   sg_jp
#
#                                                Source_URL
# 3246    https://www.tripadvisor.com/ShowTopic-g293921-...
# 3247    https://www.tripadvisor.com/ShowTopic-g293921-...
# 3248    https://www.tripadvisor.com/ShowTopic-g293921-...
# 6790    https://www.tripadvisor.com/ShowTopic-g293921-...
# 6791    https://www.tripadvisor.com/ShowTopic-g293921-...
# ...                                                   ...
# 682450  https://www.tripadvisor.com/ShowTopic-g293921-...
# 682451  https://www.tripadvisor.com/ShowTopic-g293921-...
# 682452  https://www.tripadvisor.com/ShowTopic-g293921-...
# 682453  https://www.tripadvisor.com/ShowTopic-g293921-...
# 682454  https://www.tripadvisor.com/ShowTopic-g293921-...
#
# [1793 rows x 14 columns]

# %%
#country is mislabelled so have to change country

comments_master['Country'] = comments_master['Country'].replace('sg_jp','vn')

# %%
comments_master.to_csv("/Users/chrtjen/Desktop/STB_GTT/STB_GTT_Step1Output/Vietnam.csv",index=False)
